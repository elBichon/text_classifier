# %%
# Import the pandas package, then use the "read_csv" function to read
# the labeled training data
import pandas as pd       
train = pd.read_csv("happy_train.csv")
print(train.shape)
print(train.columns.values)
train = train[['User_ID', 'Is_Response', 'Description']]
print(train.shape)
print(train.columns.values)
# Out:
# (38932, 5)
# ['User_ID' 'Description' 'Browser_Used' 'Device_Used' 'Is_Response']
# (38932, 3)
# ['User_ID' 'Is_Response' 'Description']

# %%
# Import BeautifulSoup into your workspace
from bs4 import BeautifulSoup             

# Initialize the BeautifulSoup object on a single movie review     
example1 = BeautifulSoup(train["Description"][0])  

# Print the raw review and then the output of get_text(), for 
# comparison
print (train["Description"][0])
print (example1.get_text())
# Out:
# The room was kind of clean but had a VERY strong smell of dogs. Generally below average but ok for a overnight stay if you're not too fussy. Would consider staying again if the price was right. Breakfast was free and just about better than nothing.
# The room was kind of clean but had a VERY strong smell of dogs. Generally below average but ok for a overnight stay if you're not too fussy. Would consider staying again if the price was right. Breakfast was free and just about better than nothing.
# /home/reuglewi/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/reuglewi/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
import re
# Use regular expressions to do a find-and-replace
letters_only = re.sub("[^a-zA-Z]",           # The pattern to search for
                      " ",                   # The pattern to replace it with
                      example1.get_text() )  # The text to search
print(letters_only)
lower_case = letters_only.lower()        # Convert to lower case
words = lower_case.split()  
print(words)
# Out:
# The room was kind of clean but had a VERY strong smell of dogs  Generally below average but ok for a overnight stay if you re not too fussy  Would consider staying again if the price was right  Breakfast was free and just about better than nothing
# ['the', 'room', 'was', 'kind', 'of', 'clean', 'but', 'had', 'a', 'very', 'strong', 'smell', 'of', 'dogs', 'generally', 'below', 'average', 'but', 'ok', 'for', 'a', 'overnight', 'stay', 'if', 'you', 're', 'not', 'too', 'fussy', 'would', 'consider', 'staying', 'again', 'if', 'the', 'price', 'was', 'right', 'breakfast', 'was', 'free', 'and', 'just', 'about', 'better', 'than', 'nothing']

# %%
import nltk
nltk.download()  # Download text data sets, including stop words


from nltk.corpus import stopwords # Import the stop word list


# Remove stop words from "words"
words = [w for w in words if not w in stopwords.words("english")]
print(words)
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# ['room', 'kind', 'clean', 'strong', 'smell', 'dogs', 'generally', 'average', 'ok', 'overnight', 'stay', 'fussy', 'would', 'consider', 'staying', 'price', 'right', 'breakfast', 'free', 'better', 'nothing']

# %%
def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
clean_review = review_to_words( train["Description"][0] )
print(clean_review)
# Out:
# room kind clean strong smell dogs generally average ok overnight stay fussy would consider staying price right breakfast free better nothing
# /home/reuglewi/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/reuglewi/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
# Get the number of reviews based on the dataframe column size
num_reviews = train["Description"].size

# Initialize an empty list to hold the clean reviews
clean_train_reviews = []

# Loop over each review; create an index i that goes from 0 to the length
# of the movie review list 
for i in range( 0, num_reviews ):
    # Call our function for each one, and add the result to the list of
    # clean reviews
    clean_train_reviews.append( review_to_words( train["Description"][i] ) )
print ("Cleaning and parsing the training set movie reviews...\n")
clean_train_reviews = []
for i in range( 0, num_reviews ):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print ("Review %d of %d\n" % ( i+1, num_reviews )   )                                                                
        clean_train_reviews.append( review_to_words( train["Description"][i] ))
# Out:
# /home/reuglewi/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/reuglewi/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
print("Creating the bag of words...\n")
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_train_reviews)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()
# Out:
# Creating the bag of words...

# %%
print(train_data_features.shape)

# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print(vocab)
# Out:
# (38, 1302)
# ['aaa', 'abandoned', 'able', 'absolute', 'abused', 'accessible', 'accommodation', 'accompaniment', 'across', 'actually', 'add', 'added', 'addicts', 'addition', 'adequate', 'adorable', 'adored', 'adults', 'advantage', 'advised', 'af', 'afford', 'affordable', 'afraid', 'afterward', 'ago', 'ahead', 'air', 'airport', 'alcatraz', 'alley', 'allways', 'almost', 'along', 'already', 'also', 'although', 'always', 'amazing', 'amount', 'amtrak', 'amuse', 'amused', 'amusingly', 'anaheim', 'angeles', 'anniversary', 'annoy', 'another', 'antipasto', 'anyone', 'anything', 'apartment', 'apples', 'appointed', 'architecture', 'area', 'areas', 'arizona', 'around', 'arrived', 'arriving', 'arts', 'ask', 'asked', 'aspect', 'atmosphere', 'attendants', 'attractions', 'august', 'available', 'ave', 'away', 'awesome', 'awoken', 'az', 'baby', 'babylon', 'back', 'bad', 'baggage', 'bags', 'balcony', 'bar', 'barely', 'bars', 'base', 'baseball', 'bath', 'bathrobe', 'bathroom', 'bathrooms', 'bay', 'bdrm', 'beach', 'bear', 'beats', 'beautiful', 'beautifully', 'bed', 'bedroom', 'beds', 'began', 'behind', 'bell', 'bellhop', 'besides', 'best', 'better', 'beware', 'beyond', 'big', 'bigger', 'bill', 'blanket', 'bliss', 'block', 'blocks', 'blvd', 'boarding', 'boardwalk', 'body', 'book', 'booked', 'borrow', 'bother', 'bothered', 'bottle', 'bottled', 'boulevard', 'boutiques', 'boys', 'bread', 'breakfast', 'breezes', 'bring', 'brisk', 'budget', 'buff', 'buffet', 'buildings', 'burgers', 'bus', 'buses', 'business', 'bustle', 'bustling', 'butter', 'butterfly', 'buy', 'buyer', 'cab', 'cafe', 'call', 'called', 'calling', 'calls', 'came', 'candy', 'cannot', 'car', 'cardio', 'carpet', 'carpeting', 'case', 'castle', 'cecil', 'cedarbrook', 'ceiling', 'center', 'central', 'centre', 'cereal', 'certain', 'certainly', 'chain', 'chairs', 'change', 'changed', 'channels', 'charge', 'charging', 'cheap', 'cheapskates', 'check', 'checked', 'checking', 'checkout', 'cheese', 'chelsea', 'children', 'china', 'chlorine', 'chocolate', 'choice', 'choose', 'chose', 'christmas', 'circle', 'city', 'claimed', 'class', 'clean', 'cleaner', 'cleanser', 'clear', 'close', 'closet', 'club', 'clubs', 'coast', 'cocktail', 'cocktails', 'coffee', 'cold', 'colleague', 'com', 'combination', 'combined', 'comedy', 'comes', 'comfortable', 'comfy', 'coming', 'common', 'compensate', 'competitive', 'complain', 'complained', 'complaint', 'complaints', 'completely', 'complimentary', 'con', 'concern', 'concidering', 'concierge', 'concisely', 'conditioner', 'conditioning', 'conference', 'confusing', 'connect', 'connection', 'consider', 'considering', 'construction', 'consulting', 'contrary', 'convenient', 'conveniently', 'cool', 'copperleaf', 'corner', 'corners', 'corridoor', 'corridors', 'cost', 'could', 'count', 'country', 'couple', 'course', 'courtesy', 'courtyard', 'coverings', 'crash', 'crashing', 'crew', 'criminalized', 'crowded', 'crowne', 'cruise', 'cup', 'current', 'customer', 'cute', 'dance', 'date', 'dated', 'day', 'days', 'deal', 'decent', 'decided', 'deck', 'decor', 'decorated', 'def', 'definately', 'definitely', 'delicious', 'delivered', 'demanding', 'demonstrated', 'denver', 'described', 'design', 'designer', 'desk', 'diego', 'different', 'dinner', 'direct', 'direction', 'directions', 'directly', 'dirty', 'discount', 'discovered', 'disneyland', 'distance', 'district', 'disturbing', 'dive', 'dog', 'dogs', 'done', 'dont', 'door', 'doors', 'double', 'downsides', 'downtown', 'drain', 'dreadfully', 'dreary', 'dresser', 'drink', 'drinks', 'driver', 'drowned', 'drunks', 'dry', 'due', 'dupoint', 'dust', 'dvd', 'ear', 'earlier', 'early', 'easily', 'easy', 'eat', 'effect', 'either', 'elaine', 'elegant', 'elevators', 'else', 'elsewhere', 'email', 'emails', 'employee', 'employees', 'encountered', 'end', 'english', 'enjoy', 'enjoyable', 'enjoyed', 'enormous', 'enough', 'enter', 'entered', 'entertainment', 'equally', 'equipment', 'equipments', 'equipped', 'errant', 'especially', 'etc', 'eve', 'even', 'evening', 'ever', ' ...

# %%
import numpy as np

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print(count, tag)
# Out:
# 1 aaa
# 1 abandoned
# 6 able
# 1 absolute
# 1 abused
# 1 accessible
# 1 accommodation
# 1 accompaniment
# 3 across
# 5 actually
# 1 add
# 2 added
# 1 addicts
# 2 addition
# 5 adequate
# 1 adorable
# 1 adored
# 4 adults
# 3 advantage
# 1 advised
# 1 af
# 1 afford
# 1 affordable
# 2 afraid
# 1 afterward
# 1 ago
# 1 ahead
# 5 air
# 2 airport
# 2 alcatraz
# 1 alley
# 1 allways
# 1 almost
# 1 along
# 3 already
# 12 also
# 2 although
# 6 always
# 4 amazing
# 1 amount
# 1 amtrak
# 1 amuse
# 1 amused
# 1 amusingly
# 1 anaheim
# 1 angeles
# 1 anniversary
# 1 annoy
# 7 another
# 1 antipasto
# 3 anyone
# 5 anything
# 1 apartment
# 1 apples
# 1 appointed
# 1 architecture
# 15 area
# 2 areas
# 1 arizona
# 14 around
# 2 arrived
# 1 arriving
# 1 arts
# 2 ask
# 2 asked
# 1 aspect
# 1 atmosphere
# 1 attendants
# 3 attractions
# 1 august
# 4 available
# 1 ave
# 9 away
# 1 awesome
# 1 awoken
# 1 az
# 1 baby
# 1 babylon
# 11 back
# 7 bad
# 1 baggage
# 1 bags
# 2 balcony
# 6 bar
# 1 barely
# 2 bars
# 1 base
# 2 baseball
# 2 bath
# 1 bathrobe
# 13 bathroom
# 1 bathrooms
# 4 bay
# 1 bdrm
# 1 beach
# 1 bear
# 1 beats
# 7 beautiful
# 1 beautifully
# 11 bed
# 3 bedroom
# 6 beds
# 1 began
# 3 behind
# 1 bell
# 1 bellhop
# 1 besides
# 5 best
# 4 better
# 1 beware
# 3 beyond
# 6 big
# 2 bigger
# 1 bill
# 1 blanket
# 1 bliss
# 1 block
# 2 blocks
# 1 blvd
# 1 boarding
# 1 boardwalk
# 2 body
# 1 book
# 7 booked
# 1 borrow
# 2 bother
# 2 bothered
# 1 bottle
# 1 bottled
# 1 boulevard
# 1 boutiques
# 1 boys
# 1 bread
# 12 breakfast
# 1 breezes
# 3 bring
# 1 brisk
# 2 budget
# 1 buff
# 4 buffet
# 2 buildings
# 1 burgers
# 1 bus
# 1 buses
# 2 business
# 1 bustle
# 2 bustling
# 2 butter
# 1 butterfly
# 2 buy
# 1 buyer
# 1 cab
# 1 cafe
# 1 call
# 4 called
# 1 calling
# 1 calls
# 2 came
# 2 candy
# 2 cannot
# 4 car
# 2 cardio
# 1 carpet
# 1 carpeting
# 2 case
# 2 castle
# 1 cecil
# 4 cedarbrook
# 2 ceiling
# 5 center
# 1 central
# 1 centre
# 1 cereal
# 1 certain
# 2 certainly
# 2 chain
# 1 chairs
# 3 change
# 1 changed
# 1 channels
# 2 charge
# 1 charging
# 1 cheap
# 1 cheapskates
# 8 check
# 10 checked
# 1 checking
# 1 checkout
# 1 cheese
# 1 chelsea
# 1 children
# 1 china
# 1 chlorine
# 1 chocolate
# 2 choice
# 1 choose
# 2 chose
# 1 christmas
# 1 circle
# 11 city
# 1 claimed
# 1 class
# 26 clean
# 2 cleaner
# 2 cleanser
# 1 clear
# 6 close
# 1 closet
# 1 club
# 1 clubs
# 1 coast
# 1 cocktail
# 1 cocktails
# 5 coffee
# 1 cold
# 1 colleague
# 7 com
# 1 combination
# 1 combined
# 1 comedy
# 1 comes
# 6 comfortable
# 1 comfy
# 2 coming
# 2 common
# 1 compensate
# 1 competitive
# 1 complain
# 1 complained
# 1 complaint
# 2 complaints
# 1 completely
# 3 complimentary
# 2 con
# 1 concern
# 1 concidering
# 5 concierge
# 1 concisely
# 2 conditioner
# 2 conditioning
# 2 conference
# 1 confusing
# 1 connect
# 1 connection
# 1 consider
# 1 considering
# 1 construction
# 1 consulting
# 3 contrary
# 2 convenient
# 1 conveniently
# 2 cool
# 1 copperleaf
# 1 corner
# 1 corners
# 1 corridoor
# 1 corridors
# 2 cost
# 7 could
# 1 count
# 1 country
# 4 couple
# 1 course
# 1 courtesy
# 1 courtyard
# 1 coverings
# 1 crash
# 1 crashing
# 1 crew
# 1 criminalized
# 2 crowded
# 1 crowne
# 1 cruise
# 2 cup
# 1 current
# 4 customer
# 1 cute
# 1 dance
# 1 date
# 1 dated
# 7 day
# 3 days
# 2 deal
# 1 decent
# 1 decided
# 1 deck
# 1 decor
# 1 decorated
# 1 def
# 1 definately
# 7 definitely
# 2 delicious
# 1 delivered
# 1 demanding
# 1 demonstrated
# 1 denver
# 1 described
# 2 design
# 2 designer
# 6 desk
# 6 diego
# 2 different
# 2 dinner
# 2 direct
# 1 direction
# 2 directions
# 1 directly
# 1 dirty
# 1 discount
# 1 discovered
# 1 disneyland
# 2 distance
# 3 district
# 1 disturbing
# 1 dive
# 2 dog
# 5 dogs
# 2 done
# 1 dont
# 2 door
# 1 doors
# 4 double
# 1 downsides
# 2 downtown
# 2 drain
# 1 dreadfully
# 1 dreary
# 1 dresser
# 1 drink
# 2 drinks
# 1 driver
# 1 drowned
# 1 drunks
# 1 dry
# 1 due
# 1 dupoint
# 1 dust
# 2 dvd
# 1 ear
# 1 earlier
# 5 early
# 1 easily
# 2 easy
# 2 eat
# 1 effect
# 3 either
# 2 elaine
# 1 elegant
# 2 elevators
# 3 else
# 2 elsewhere
# 1 email
# 1 emails
# 1 employee
# 1 employees
# 2 encountered
# 1 end
# 1 english
# 1 enjoy
# 2 enjoyable
# 4 enjoyed
# 1 enormous
# 4 enough
# 1 enter
# 1 entered
# 1 entertainment
# 1 equally
# 2 equipment
# 1 equipments
# 2 equipped
# 1 errant
# 4 especially
# 1 etc
# 1 eve
# 8 even
# 4 evening
# 4 ever
# 6 every
# 1 everybody
# 2 everyone
# 12 everything
# 1 everywhere
# 1 evidently
# 1 exact
# 1 exactly
# 1 example
# 1 excellant
# 1 excellence
# 5 excellent
# 1 except
# 2 exception
# 1 exceptional
# 1 exceptionally
# 1 excess
# 1 exercise
# 1 exhausted
# 1 exit
# 3 expect
# 2 expectations
# 2 expected
# 1 expensive
# 5 experience
# 1 explain
# 1 express
# 1 extensive
# 1 extra
# 5 extremely
# 2 facial
# 1 facilities
# 2 facility
# 1 fact
# 3 fairly
# 1 fairway
# 1 familiar
# 6 family
# 1 fan
# 1 fanatic
# 1 fancy
# 1 fans
# 3 fantastic
# 1 far
# 1 feb
# 1 february
# 1 fee
# 1 feel
# 1 fenway
# 2 fi
# 1 filers
# 1 filled
# 1 filters
# 1 finally
# 1 financial
# 3 find
# 1 finding
# 4 fine
# 1 firepits
# 1 fireplace
# 7 first
# 2 fit
# 4 fitness
# 1 fits
# 1 fixed
# 1 flat
# 16 floor
# 1 floors
# 1 florid
# 2 folks
# 1 food
# 1 forgot
# 2 forgotten
# 1 forward
# 3 found
# 2 francisco
# 1 franklky
# 1 freaking
# 13 free
# 1 freezer
# 3 fresh
# 4 fridge
# 1 friend
# 12 friendly
# 2 friends
# 5 front
# 1 frozen
# 1 frustrating
# 5 full
# 2 fun
# 1 functional
# 1 furnished
# 1 fussy
# 1 gallon
# 3 game
# 1 games
# 1 garden
# 1 gas
# 1 gave
# 1 gawk
# 1 gel
# 1 gem
# 1 gere
# 1 germantown
# 7 get
# 2 getaway
# 2 getting
# 1 girl
# 1 give
# 2 given
# 1 giving
# 1 glad
# 1 glass
# 7 go
# 1 god
# 8 going
# 1 gold
# 17 good
# 1 gorgeous
# 4 got
# 1 gotten
# 1 graduation
# 1 graffiti
# 1 grammarian
# 7 grand
# 1 granddaughter
# 27 great
# 1 grippers
# 3 grounds
# 5 guest
# 1 guests
# 4 gym
# 1 gyms
# 1 hair
# 3 half
# 2 hallway
# 2 hallways
# 1 handy
# 1 hanging
# 1 happening
# 1 happier
# 4 happy
# 1 harbor
# 3 hard
# 1 hardly
# 1 harm
# 2 hated
# 1 hbo
# 1 hd
# 3 heading
# 1 heard
# 1 heart
# 1 heat
# 1 heated
# 1 heavens
# 1 heck
# 1 helicopters
# 2 help
# 8 helpful
# 1 helpped
# 1 hicup
# 1 high
# 2 higher
# 3 highly
# 1 highway
# 2 hill
# 1 hills
# 2 hilton
# 1 historical
# 1 history
# 1 holiday
# 6 hollywood
# 2 home
# 2 homeless
# 2 honestly
# 1 hooked
# 2 hop
# 1 hope
# 1 horror
# 4 hot
# 68 hotel
# 9 hotels
# 1 hours
# 1 house
# 2 housekeeping
# 3 however
# 1 hr
# 3 huge
# 1 hung
# 3 husband
# 1 hustle
# 5 hyatt
# 1 hype
# 3 idea
# 1 images
# 1 imagine
# 1 implies
# 2 important
# 1 impossible
# 1 impressed
# 1 impressive
# 1 improve
# 1 improved
# 1 improvement
# 3 included
# 2 including
# 1 incorrect
# 1 incrediably
# 1 incredibly
# 3 indigo
# 3 inn
# 4 instead
# 1 intelligent
# 1 interior
# 4 internet
# 1 intrusive
# 3 invite
# 1 issue
# 1 issues
# 1 italian
# 1 item
# 2 items
# 1 itmes
# 1 jacuzzi
# 1 jacuzzis
# 1 jane
# 2 job
# 1 jobs
# 1 join
# 1 joke
# 1 juices
# 2 july
# 1 jw
# 1 keep
# 1 keeping
# 1 keepsake
# 2 kept
# 1 key
# 4 kids
# 4 kimpton
# 2 kind
# 2 king
# 4 kitchen
# 2 kitchenette
# 1 kitsch
# 2 know
# 2 knowing
# 1 kps
# 1 lacking
# 1 landmarks
# 1 laptop
# 7 large
# 4 last
# 1 late
# 1 latter
# 2 laundry
# 1 leading
# 3 left
# 1 less
# 4 let
# 1 lets
# 1 letting
# 1 levels
# 1 lexington
# 1 library
# 1 lifesaver
# 1 lighting
# 12 like
# 1 liked
# 2 limited
# 1 line
# 1 list
# 1 listening
# 11 little
# 1 live
# 1 lives
# 3 living
# 1 liz
# 11 lobby
# 2 located
# 15 location
# 1 loft
# 1 loitering
# 1 long
# 3 look
# 1 looked
# 3 looking
# 1 los
# 6 lot
# 8 lots
# 2 loud
# 1 lounge
# 2 love
# 7 loved
# 3 lovely
# 3 low
# 2 lower
# 1 luckily
# 3 luggage
# 1 lukewarm
# 1 lunch
# 1 machines
# 1 mad
# 1 madam
# 10 made
# 2 magic
# 2 magnificent
# 1 maid
# 1 maintained
# 4 make
# 2 maker
# 1 makes
# 1 making
# 1 mall
# 1 manage
# 2 management
# 3 manager
# 1 manchester
# 1 manhattan
# 5 many
# 1 maps
# 2 marriott
# 4 maybe
# 1 meals
# 1 measured
# 1 meats
# 1 meditation
# 2 meeting
# 1 memphis
# 1 mentioned
# 1 metro
# 1 micro
# 5 microwave
# 1 mid
# 1 midst
# 3 might
# 1 mildew
# 1 mile
# 2 mind
# 2 mine
# 5 mini
# 2 minute
# 5 minutes
# 1 mixers
# 1 mixing
# 4 modern
# 1 modifies
# 2 mom
# 1 moment
# 1 moments
# 6 money
# 1 months
# 5 morning
# 1 motel
# 1 motorized
# 1 movie
# 2 moving
# 5 much
# 1 mum
# 1 museum
# 1 music
# 1 musical
# 1 must
# 2 mystery
# 1 name
# 1 nap
# 2 nature
# 1 navy
# 4 near
# 1 nearby
# 1 neatly
# 6 need
# 8 needed
# 1 neither
# 1 nervous
# 3 never
# 6 new
# 1 newbury
# 1 newly
# 7 next
# 23 nice
# 2 nicely
# 1 nicer
# 15 night
# 1 nightmare
# 4 nights
# 1 nobady
# 6 noise
# 3 noisy
# 1 northwestern
# 1 nosiy
# 1 note
# 1 noted
# 3 nothing
# 1 notice
# 1 nowhere
# 1 number
# 1 ny
# 6 nyc
# 1 oasis
# 1 ocean
# 1 oceanfront
# 1 october
# 1 odd
# 1 odors
# 2 offered
# 1 offers
# 1 oh
# 1 ok
# 2 old
# 22 one
# 1 open
# 2 opened
# 1 opt
# 1 options
# 1 order
# 1 ordered
# 1 originally
# 2 others
# 4 otherwise
# 1 outperformed
# 3 outside
# 2 outstanding
# 4 overall
# 1 overlooking
# 1 overpriced
# 1 pacific
# 1 package
# 1 paid
# 1 paint
# 1 pair
# 1 pajamas
# 1 pantry
# 4 park
# 4 parking
# 2 part
# 2 particularly
# 2 partner
# 1 party
# 1 passes
# 1 passport
# 1 patience
# 1 pay
# 1 paying
# 1 peaceful
# 1 peeling
# 1 peerfect
# 1 penthouse
# 7 people
# 5 perfect
# 1 perfectly
# 1 performers
# 1 period
# 6 person
# 1 petco
# 1 phenomenal
# 1 photographs
# 1 piano
# 1 picked
# 2 picture
# 2 pictures
# 7 pillows
# 1 pinch
# 9 place
# 1 places
# 1 plan
# 1 planned
# 3 planning
# 1 plates
# 1 player
# 1 playing
# 1 plaza
# 2 pleasant
# 3 please
# 2 pleased
# 1 plugs
# 3 plus
# 1 pluses
# 5 pm
# 1 point
# 1 pointed
# 2 policy
# 1 polite
# 7 pool
# 1 pools
# 3 popcorn
# 1 positive
# 2 possible
# 1 possibly
# 1 potential
# 1 powered
# 2 precipitation
# 1 precise
# 1 preservationist
# 3 pretty
# 6 price
# 1 pricey
# 1 print
# 1 printed
# 4 prior
# 1 privacy
# 1 problem
# 2 proceeded
# 3 professional
# 1 program
# 1 progress
# 2 properties
# 3 property
# 2 prose
# 1 provide
# 4 provided
# 1 provides
# 1 providing
# 1 proximity
# 1 prudential
# 1 pub
# 2 public
# 1 pump
# 2 purchase
# 1 purchased
# 1 pushy
# 4 put
# 1 queen
# 1 questions
# 2 quick
# 1 quickly
# 6 quiet
# 6 quite
# 3 rain
# 3 range
# 2 rate
# 4 rates
# 1 rather
# 1 rd
# 1 read
# 1 ready
# 2 real
# 1 realized
# 11 really
# 1 reason
# 2 reasonable
# 1 rebook
# 1 reccommend
# 2 recent
# 3 recently
# 1 reception
# 1 receptionist
# 7 recommend
# 2 recommended
# 1 recommending
# 1 reduction
# 2 refrigerator
# 1 refund
# 1 refurbished
# 1 regreted
# 1 relative
# 1 relax
# 1 reliable
# 2 remodeled
# 1 renovated
# 2 renovation
# 1 renovations
# 2 rental
# 2 requested
# 1 reservation
# 1 reservations
# 1 resort
# 7 restaurant
# 5 restaurants
# 1 restraunt
# 1 return
# 5 reviews
# 1 rewriting
# 1 ride
# 1 ridiculously
# 7 right
# 2 road
# 1 rock
# 1 rocking
# 2 rollaway
# 1 roof
# 49 room
# 22 rooms
# 1 roomy
# 1 rude
# 1 run
# 1 rundown
# 6 safe
# 3 said
# 1 sake
# 1 sale
# 8 san
# 2 sat
# 1 saturday
# 2 save
# 3 saw
# 6 say
# 1 says
# 1 scala
# 1 scary
# 1 scattered
# 1 seaport
# 1 searched
# 1 seatac
# 1 seating
# 2 seattle
# 5 second
# 1 section
# 5 see
# 2 seeing
# 1 seem
# 4 seemed
# 1 selection
# 1 send
# 1 sensitive
# 2 sent
# 4 sentence
# 2 separate
# 1 serve
# 1 serves
# 12 service
# 1 services
# 2 set
# 1 setting
# 1 sever
# 2 several
# 1 sfo
# 1 shade
# 1 shampoo
# 1 shape
# 1 shared
# 1 shares
# 1 sharing
# 1 sheets
# 3 shelter
# 1 ships
# 1 shop
# 1 shopping
# 1 shops
# 1 shopworn
# 1 shore
# 1 short
# 1 showed
# 4 shower
# 1 showering
# 1 shuttle
# 1 side
# 1 sidewalk
# 1 sign
# 1 signing
# 5 signs
# 1 similarly
# 1 simply
# 4 since
# 3 single
# 2 sink
# 1 sister
# 2 sit
# 4 site
# 2 size
# 4 sized
# 1 slamming
# 4 sleep
# 1 sleeper
# 4 sleeping
# 2 slept
# 2 slightly
# 1 slippy
# 1 sliverware
# 1 slow
# 10 small
# 2 smaller
# 1 smart
# 1 smell
# 2 smelled
# 1 smelling
# 3 snacks
# 1 sofa
# 2 soft
# 1 sold
# 1 solo
# 1 somekind
# 2 someone
# 3 something
# 1 somewhat
# 1 somewhere
# 2 son
# 1 soon
# 2 sound
# 1 space
# 1 spam
# 2 speak
# 3 special
# 1 specials
# 1 specifically
# 1 split
# 2 spot
# 1 spread
# 1 sq
# 3 square
# 2 st
# 1 stadium
# 16 staff
# 1 stains
# 1 standard
# 1 standards
# 1 star
# 1 starbucks
# 1 stars
# 2 station
# 23 stay
# 1 staybridge
# 1 staycation
# 23 stayed
# 8 staying
# 3 still
# 1 stocked
# 2 stops
# 2 store
# 1 stored
# 1 stores
# 1 straight
# 5 street
# 1 streets
# 1 stroller
# 2 stuck
# 1 students
# 1 studio
# 1 stunning
# 1 subject
# 2 subway
# 2 success
# 1 suggestions
# 1 suit
# 1 suite
# 2 suites
# 1 summer
# 1 sunday
# 2 super
# 1 superior
# 1 supermarket
# 1 supposedly
# 3 sure
# 2 surprise
# 1 surprised
# 2 surrounding
# 1 swanky
# 1 swim
# 1 tables
# 6 take
# 1 takeaway
# 1 talk
# 1 talked
# 1 tastefully
# 2 tea
# 1 tell
# 1 tended
# 1 tenderloin
# 1 tenders
# 1 terrible
# 1 terrific
# 6 th
# 1 theatre
# 1 therefore
# 2 thing
# 6 things
# 5 think
# 4 though
# 1 thought
# 2 three
# 1 throughout
# 1 thru
# 2 tickets
# 1 tidy
# 1 tier
# 14 time
# 7 times
# 1 tip
# 1 together
# 4 toiletries
# 2 told
# 5 took
# 1 toothbrush
# 3 top
# 1 tossed
# 2 totally
# 1 tote
# 1 touches
# 1 tour
# 1 tourist
# 1 tourists
# 1 tours
# 2 town
# 1 traffic
# 1 train
# 1 trained
# 1 trains
# 4 transportation
# 1 traveled
# 1 traveler
# 1 traveling
# 1 travellers
# 1 travels
# 1 treadmills
# 1 treated
# 2 tried
# 11 trip
# 3 tripadvisor
# 1 trouble
# 2 try
# 1 trying
# 1 tub
# 1 tubs
# 1 turned
# 5 tv
# 9 two
# 1 type
# 4 umbrella
# 1 umbrellas
# 1 unacceptable
# 1 undergoing
# 1 unease
# 1 unexpectedly
# 3 union
# 1 unlike
# 1 unseen
# 1 unusual
# 1 upgrade
# 2 upgraded
# 1 upper
# 1 upscale
# 1 upstairs
# 1 uptown
# 18 us
# 8 use
# 3 used
# 1 usual
# 1 utensils
# 2 utilize
# 2 vacation
# 1 valet
# 1 value
# 3 valued
# 2 various
# 1 vegas
# 2 vent
# 1 verb
# 1 verbose
# 8 view
# 7 views
# 3 villa
# 1 village
# 2 visit
# 1 waffle
# 1 waffles
# 1 waiting
# 6 walk
# 2 walked
# 3 walking
# 5 wall
# 1 want
# 3 wanted
# 1 warning
# 1 watch
# 1 watched
# 1 watching
# 4 water
# 1 wave
# 1 waves
# 3 way
# 1 ways
# 1 weak
# 1 wear
# 1 weather
# 2 website
# 2 week
# 2 weekend
# 2 weeks
# 2 weights
# 13 well
# 9 went
# 1 west
# 1 western
# 2 westin
# 1 whenever
# 1 whereas
# 1 whimsically
# 1 white
# 1 whitesox
# 3 whole
# 2 wi
# 1 wife
# 2 wifi
# 4 window
# 2 windows
# 3 wine
# 2 wireless
# 1 wish
# 1 wisked
# 2 within
# 2 without
# 6 wonderful
# 1 woody
# 1 wording
# 4 work
# 3 worked
# 1 workers
# 1 working
# 1 world
# 1 worlds
# 1 worse
# 1 worst
# 3 worth
# 24 would
# 3 wow
# 1 writes
# 1 writing
# 1 written
# 1 wrong
# 1 yamashiro
# 5 year
# 3 years
# 2 yes
# 1 york
# 2 young

# %%
from sklearn.model_selection import train_test_split    

print("Training the random forest...")
from sklearn.ensemble import RandomForestClassifier


#X = train_data_features
#y = train["Is_Response"]
# Initialize a Random Forest classifier with 100 trees
#X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.05)
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
# This may take a few minutes to run

forest = forest.fit(train_data_features, train["Is_Response"])
# Out:
# Training the random forest...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-f71d7bc3017d> in <module>()
#      16 # This may take a few minutes to run
#      17
# ---> 18 forest = forest.fit(train_data_features, train["Is_Response"])
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     326                     t, self, X, y, sample_weight, i, len(trees),
#     327                     verbose=self.verbose, class_weight=self.class_weight)
# --> 328                 for i, t in enumerate(trees))
#     329
#     330             # Collect newly grown trees
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     119             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     120
# --> 121         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     122     else:
#     123         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     234         if len(y) != n_samples:
#     235             raise ValueError("Number of labels=%d does not match "
# --> 236                              "number of samples=%d" % (len(y), n_samples))
#     237         if not 0 <= self.min_weight_fraction_leaf <= 0.5:
#     238             raise ValueError("min_weight_fraction_leaf must in [0, 0.5]")
#
# ValueError: Number of labels=38932 does not match number of samples=38

# %%
# Import the pandas package, then use the "read_csv" function to read
# the labeled training data
import pandas as pd       
train = pd.read_csv("train.csv")
print(train.shape)
print(train.columns.values)
train = train[['id', 'text', 'author']]
print(train.shape)
print(train.columns.values)
print(train.head())
# Out:
# (19579, 3)
# ['id' 'text' 'author']
# (19579, 3)
# ['id' 'text' 'author']
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL

# %%
# Import BeautifulSoup into your workspace
from bs4 import BeautifulSoup             

# Initialize the BeautifulSoup object on a single movie review     
example1 = BeautifulSoup(train["text"][0])  

# Print the raw review and then the output of get_text(), for 
# comparison
print(train["text"][0])
print(example1.get_text())
# Out:
# This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set out, without being aware of the fact; so perfectly uniform seemed the wall.
# This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set out, without being aware of the fact; so perfectly uniform seemed the wall.
# /home/reuglewi/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/reuglewi/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
import re
# Use regular expressions to do a find-and-replace
letters_only = re.sub("[^a-zA-Z]",           # The pattern to search for
                      " ",                   # The pattern to replace it with
                      example1.get_text() )  # The text to search
print(letters_only)
# Out:
# This process  however  afforded me no means of ascertaining the dimensions of my dungeon  as I might make its circuit  and return to the point whence I set out  without being aware of the fact  so perfectly uniform seemed the wall

# %%
lower_case = letters_only.lower()      
print(lower_case)
words = lower_case.split()     
print(words)
# Out:
# this process  however  afforded me no means of ascertaining the dimensions of my dungeon  as i might make its circuit  and return to the point whence i set out  without being aware of the fact  so perfectly uniform seemed the wall
# ['this', 'process', 'however', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'of', 'my', 'dungeon', 'as', 'i', 'might', 'make', 'its', 'circuit', 'and', 'return', 'to', 'the', 'point', 'whence', 'i', 'set', 'out', 'without', 'being', 'aware', 'of', 'the', 'fact', 'so', 'perfectly', 'uniform', 'seemed', 'the', 'wall']

# %%
import nltk
nltk.download()  # Download text data sets, including stop words
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords # Import the stop word list
words = [w for w in words if not w in stopwords.words("english")]
print(stopwords.words("english"))
# Remove stop words from "words"
words = [w for w in words if not w in stopwords.words("english")]
print(words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']
# ['process', 'however', 'afforded', 'means', 'ascertaining', 'dimensions', 'dungeon', 'might', 'make', 'circuit', 'return', 'point', 'whence', 'set', 'without', 'aware', 'fact', 'perfectly', 'uniform', 'seemed', 'wall']

# %%
def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
clean_review = review_to_words( train["text"][0] )
print (clean_review)
# Out:
# process however afforded means ascertaining dimensions dungeon might make circuit return point whence set without aware fact perfectly uniform seemed wall
# /home/reuglewi/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/reuglewi/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
# Get the number of reviews based on the dataframe column size
num_reviews = train["text"].size

# Initialize an empty list to hold the clean reviews
clean_train_reviews = []

# Loop over each review; create an index i that goes from 0 to the length
# of the movie review list 
for i in range( 0, num_reviews ):
    # Call our function for each one, and add the result to the list of
    # clean reviews
    clean_train_reviews.append( review_to_words( train["text"][i] ) )
print ("Cleaning and parsing the training set movie reviews...\n")
clean_train_reviews = []
for i in range( 0, num_reviews ):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print ("Review %d of %d\n" % ( i+1, num_reviews ))                                                                   
    clean_train_reviews.append( review_to_words( train["text"][i] ))
# Out:
# /home/reuglewi/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/reuglewi/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Cleaning and parsing the training set movie reviews...
#
# Review 1000 of 19579
#
# Review 2000 of 19579
#
# Review 3000 of 19579
#
# Review 4000 of 19579
#
# Review 5000 of 19579
#
# Review 6000 of 19579
#
# Review 7000 of 19579
#
# Review 8000 of 19579
#
# Review 9000 of 19579
#
# Review 10000 of 19579
#
# Review 11000 of 19579
#
# Review 12000 of 19579
#
# Review 13000 of 19579
#
# Review 14000 of 19579
#
# Review 15000 of 19579
#
# Review 16000 of 19579
#
# Review 17000 of 19579
#
# Review 18000 of 19579
#
# Review 19000 of 19579

# %%
print ("Creating the bag of words...\n")
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_train_reviews)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()
print('done')
# Out:
# Creating the bag of words...
#
# done

# %%
# Read the test data
test = pd.read_csv("test.csv",)

# Verify that there are 25,000 rows and 2 columns
test = test[['id', 'text']]
print(test.shape)
print(test.columns.values)
print(test["text"][0])
# Create an empty list and append the clean reviews one by one
num_reviews = len(test["text"])
clean_test_reviews = [] 

print ("Cleaning and parsing the test set movie reviews...\n")
for i in range(0,num_reviews):
    if( (i+1) % 1000 == 0 ):
        print ("Review %d of %d\n" % (i+1, num_reviews))
        clean_review = review_to_words( test["text"][i])
        clean_test_reviews.append( clean_review )

# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_reviews)
test_data_features = test_data_features.toarray()

# Use the random forest to make sentiment label predictions
result = forest.predict(test_data_features)

# Copy the results to a pandas dataframe with an "id" column and
# a "sentiment" column
output = pd.DataFrame( data={"id":test["id"], "text":result} )

# Use pandas to write the comma-separated output file
output.to_csv( "Bag_of_Words_model.csv", index=False, quoting=3 )
# Out:
# (8392, 2)
# ['id' 'text']
# Still, as I urged our leaving Ireland with such inquietude and impatience, my father thought it best to yield.
# Cleaning and parsing the test set movie reviews...
#
# Review 1000 of 8392
#
# Review 2000 of 8392
#
# Review 3000 of 8392
#
# Review 4000 of 8392
#
# Review 5000 of 8392
#
# Review 6000 of 8392
#
# Review 7000 of 8392
#
# Review 8000 of 8392
# /home/reuglewi/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/reuglewi/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2619405ed54f> in <module>()
#      26
#      27 # Use the random forest to make sentiment label predictions
# ---> 28 result = forest.predict(test_data_features)
#      29
#      30 # Copy the results to a pandas dataframe with an "id" column and
#
# NameError: name 'forest' is not defined

# %%
print (train_data_features.shape)
# Out:
# (19579, 5000)

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print(vocab)
# Out:
# ['abandon', 'abandoned', 'abaout', 'abhorred', 'ability', 'able', 'abnormal', 'abode', 'abroad', 'abruptly', 'absence', 'absent', 'absolute', 'absolutely', 'absorbed', 'absurd', 'abyss', 'abysses', 'academy', 'accents', 'accept', 'access', 'accident', 'accidentally', 'accidents', 'accompanied', 'accompany', 'accomplish', 'accomplished', 'accomplishment', 'according', 'accordingly', 'account', 'accounts', 'accurately', 'accursed', 'accused', 'accustomed', 'acknowledge', 'acknowledged', 'acquaintance', 'acquainted', 'acquired', 'across', 'act', 'acted', 'action', 'actions', 'active', 'activity', 'acts', 'actual', 'actually', 'acute', 'adapted', 'add', 'added', 'adding', 'addition', 'additional', 'address', 'addressed', 'admirable', 'admiration', 'admired', 'admit', 'admitted', 'adopted', 'adoration', 'adored', 'adorned', 'adrian', 'advance', 'advanced', 'advancing', 'advantage', 'advantages', 'adventure', 'adversary', 'advice', 'aeons', 'aether', 'afar', 'affair', 'affairs', 'affected', 'affection', 'affectionate', 'affections', 'afflicted', 'afford', 'afforded', 'affording', 'afore', 'afraid', 'africa', 'african', 'afternoon', 'afterward', 'afterwards', 'agatha', 'age', 'aged', 'agency', 'agent', 'ages', 'aghast', 'agin', 'agitated', 'agitation', 'ago', 'agonies', 'agonizing', 'agony', 'agreeable', 'agreed', 'ah', 'ahead', 'aid', 'aim', 'air', 'aira', 'airs', 'akin', 'alarm', 'alarmed', 'alas', 'albany', 'alfred', 'alien', 'alienage', 'alike', 'alive', 'alley', 'alleys', 'allow', 'allowed', 'alluded', 'almost', 'alone', 'along', 'aloud', 'already', 'also', 'altar', 'alter', 'alteration', 'altered', 'although', 'altitude', 'altogether', 'always', 'amazement', 'ambition', 'ambitious', 'america', 'american', 'amiable', 'amid', 'amidst', 'among', 'amongst', 'amount', 'ample', 'amused', 'amusement', 'analogy', 'analysis', 'ancestor', 'ancestors', 'ancient', 'angel', 'angelic', 'angell', 'angels', 'anger', 'angle', 'angles', 'angry', 'anguish', 'animal', 'animals', 'animated', 'annihilation', 'anon', 'another', 'answer', 'answered', 'antagonist', 'antique', 'antiquity', 'anxiety', 'anxious', 'anyone', 'anything', 'aout', 'apart', 'apartment', 'apartments', 'ape', 'aperture', 'appalling', 'apparatus', 'apparent', 'apparently', 'appeal', 'appear', 'appearance', 'appearances', 'appeared', 'appears', 'appetite', 'application', 'applied', 'apply', 'appointed', 'apprehended', 'apprehension', 'approach', 'approached', 'approaching', 'april', 'arabian', 'arch', 'archaic', 'architecture', 'ardent', 'ardour', 'argument', 'arguments', 'arise', 'arisen', 'arising', 'arkham', 'arm', 'armitage', 'arms', 'army', 'arose', 'around', 'aroused', 'arranged', 'arrangement', 'arrangements', 'arranging', 'arrested', 'arrival', 'arrive', 'arrived', 'arrives', 'art', 'arter', 'arthur', 'article', 'articles', 'articulate', 'artificial', 'artist', 'arts', 'ascend', 'ascended', 'ascending', 'ascent', 'ascertain', 'ascertained', 'ashamed', 'ashes', 'asia', 'aside', 'ask', 'asked', 'asleep', 'aspect', 'assassins', 'assembled', 'assembly', 'assert', 'asserted', 'assertion', 'assigned', 'assist', 'assistance', 'associated', 'associates', 'association', 'associations', 'assume', 'assumed', 'assuming', 'assure', 'assured', 'assuredly', 'astonished', 'astonishing', 'astonishment', 'astronomers', 'astronomical', 'asylum', 'atal', 'ate', 'athens', 'atlantic', 'atmosphere', 'atmospheric', 'atrocity', 'attached', 'attachment', 'attack', 'attain', 'attained', 'attempt', 'attempted', 'attempting', 'attempts', 'attend', 'attendance', 'attendant', 'attendants', 'attended', 'attending', 'attention', 'attentions', 'attentively', 'attic', 'attracted', 'attributed', 'au', 'audible', 'audience', 'aught', 'augmented', 'august', 'aunt', 'author', 'authorities', 'authority', 'automaton', 'autumn', 'avalanche', 'avenue', 'average', 'avoid', 'avoided', 'awaited', 'awaiting', 'awake', 'awaked', 'awaken', 'awakened', 'awakening', 'awaking', 'aware', 'away', 'awe', 'awful', 'awhile', 'awo ...

# %%
import numpy as np

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print(count, tag)
# Out:
# 11 abandon
# 29 abandoned
# 24 abaout
# 12 abhorred
# 14 ability
# 67 able
# 21 abnormal
# 39 abode
# 16 abroad
# 21 abruptly
# 66 absence
# 23 absent
# 33 absolute
# 42 absolutely
# 25 absorbed
# 16 absurd
# 28 abyss
# 30 abysses
# 10 academy
# 20 accents
# 13 accept
# 13 access
# 43 accident
# 10 accidentally
# 10 accidents
# 30 accompanied
# 26 accompany
# 17 accomplish
# 31 accomplished
# 12 accomplishment
# 24 according
# 29 accordingly
# 126 account
# 15 accounts
# 10 accurately
# 40 accursed
# 12 accused
# 39 accustomed
# 9 acknowledge
# 10 acknowledged
# 32 acquaintance
# 23 acquainted
# 33 acquired
# 89 across
# 63 act
# 18 acted
# 68 action
# 36 actions
# 22 active
# 19 activity
# 14 acts
# 36 actual
# 54 actually
# 32 acute
# 23 adapted
# 20 add
# 58 added
# 10 adding
# 12 addition
# 14 additional
# 20 address
# 29 addressed
# 14 admirable
# 42 admiration
# 11 admired
# 36 admit
# 42 admitted
# 21 adopted
# 9 adoration
# 11 adored
# 14 adorned
# 141 adrian
# 25 advance
# 43 advanced
# 10 advancing
# 19 advantage
# 11 advantages
# 17 adventure
# 12 adversary
# 20 advice
# 14 aeons
# 10 aether
# 11 afar
# 31 affair
# 21 affairs
# 27 affected
# 88 affection
# 20 affectionate
# 34 affections
# 10 afflicted
# 37 afford
# 38 afforded
# 9 affording
# 9 afore
# 29 afraid
# 9 africa
# 9 african
# 54 afternoon
# 55 afterward
# 42 afterwards
# 21 agatha
# 117 age
# 43 aged
# 15 agency
# 12 agent
# 27 ages
# 17 aghast
# 10 agin
# 26 agitated
# 42 agitation
# 79 ago
# 14 agonies
# 10 agonizing
# 56 agony
# 11 agreeable
# 38 agreed
# 38 ah
# 43 ahead
# 51 aid
# 16 aim
# 240 air
# 20 aira
# 12 airs
# 13 akin
# 23 alarm
# 17 alarmed
# 75 alas
# 9 albany
# 19 alfred
# 20 alien
# 9 alienage
# 16 alike
# 72 alive
# 11 alley
# 11 alleys
# 33 allow
# 26 allowed
# 15 alluded
# 232 almost
# 254 alone
# 100 along
# 32 aloud
# 141 already
# 207 also
# 15 altar
# 13 alter
# 28 alteration
# 26 altered
# 260 although
# 10 altitude
# 106 altogether
# 169 always
# 14 amazement
# 44 ambition
# 11 ambitious
# 24 america
# 15 american
# 17 amiable
# 34 amid
# 53 amidst
# 280 among
# 24 amongst
# 25 amount
# 11 ample
# 12 amused
# 21 amusement
# 9 analogy
# 20 analysis
# 14 ancestor
# 14 ancestors
# 163 ancient
# 34 angel
# 11 angelic
# 13 angell
# 17 angels
# 25 anger
# 27 angle
# 33 angles
# 23 angry
# 45 anguish
# 63 animal
# 29 animals
# 21 animated
# 10 annihilation
# 10 anon
# 250 another
# 67 answer
# 36 answered
# 25 antagonist
# 33 antique
# 21 antiquity
# 49 anxiety
# 42 anxious
# 11 anyone
# 82 anything
# 41 aout
# 28 apart
# 60 apartment
# 19 apartments
# 10 ape
# 20 aperture
# 15 appalling
# 19 apparatus
# 76 apparent
# 81 apparently
# 10 appeal
# 72 appear
# 131 appearance
# 13 appearances
# 215 appeared
# 37 appears
# 13 appetite
# 23 application
# 34 applied
# 14 apply
# 13 appointed
# 10 apprehended
# 26 apprehension
# 34 approach
# 66 approached
# 37 approaching
# 22 april
# 15 arabian
# 21 arch
# 13 archaic
# 16 architecture
# 28 ardent
# 14 ardour
# 17 argument
# 17 arguments
# 24 arise
# 12 arisen
# 20 arising
# 59 arkham
# 99 arm
# 34 armitage
# 102 arms
# 29 army
# 92 arose
# 227 around
# 27 aroused
# 29 arranged
# 23 arrangement
# 16 arrangements
# 12 arranging
# 27 arrested
# 36 arrival
# 27 arrive
# 80 arrived
# 11 arrives
# 76 art
# 14 arter
# 26 arthur
# 28 article
# 33 articles
# 13 articulate
# 30 artificial
# 33 artist
# 18 arts
# 17 ascend
# 22 ascended
# 13 ascending
# 20 ascent
# 11 ascertain
# 20 ascertained
# 9 ashamed
# 12 ashes
# 13 asia
# 45 aside
# 50 ask
# 83 asked
# 19 asleep
# 51 aspect
# 11 assassins
# 20 assembled
# 11 assembly
# 11 assert
# 9 asserted
# 10 assertion
# 12 assigned
# 18 assist
# 21 assistance
# 18 associated
# 10 associates
# 16 association
# 10 associations
# 11 assume
# 39 assumed
# 11 assuming
# 17 assure
# 47 assured
# 16 assuredly
# 26 astonished
# 15 astonishing
# 37 astonishment
# 10 astronomers
# 11 astronomical
# 12 asylum
# 17 atal
# 15 ate
# 21 athens
# 12 atlantic
# 84 atmosphere
# 10 atmospheric
# 9 atrocity
# 27 attached
# 20 attachment
# 13 attack
# 13 attain
# 41 attained
# 69 attempt
# 20 attempted
# 13 attempting
# 24 attempts
# 28 attend
# 11 attendance
# 16 attendant
# 13 attendants
# 47 attended
# 22 attending
# 137 attention
# 9 attentions
# 9 attentively
# 28 attic
# 24 attracted
# 18 attributed
# 10 au
# 10 audible
# 13 audience
# 12 aught
# 11 augmented
# 26 august
# 29 aunt
# 30 author
# 9 authorities
# 20 authority
# 45 automaton
# 29 autumn
# 10 avalanche
# 13 avenue
# 12 average
# 25 avoid
# 23 avoided
# 15 awaited
# 10 awaiting
# 38 awake
# 18 awaked
# 20 awaken
# 26 awakened
# 15 awakening
# 11 awaking
# 57 aware
# 295 away
# 27 awe
# 44 awful
# 15 awhile
# 40 awoke
# 11 axis
# 300 back
# 11 background
# 33 bad
# 32 bade
# 10 badly
# 12 bag
# 16 ballast
# 77 balloon
# 15 band
# 10 bandage
# 9 banished
# 18 bank
# 26 banks
# 9 bar
# 23 bare
# 14 barely
# 17 bark
# 13 barn
# 30 baron
# 15 barren
# 10 barri
# 17 barrier
# 11 barriers
# 19 barry
# 19 barzai
# 17 bas
# 35 base
# 9 bats
# 21 battle
# 11 bay
# 14 baying
# 14 beach
# 16 beam
# 23 beams
# 65 bear
# 19 beard
# 30 bearded
# 43 bearing
# 10 bears
# 25 beast
# 16 beasts
# 37 beat
# 22 beating
# 11 beauties
# 92 beautiful
# 155 beauty
# 20 beauvais
# 295 became
# 171 become
# 22 becomes
# 21 becoming
# 98 bed
# 14 beetle
# 12 beg
# 187 began
# 11 begged
# 28 begin
# 45 beginning
# 35 begun
# 88 beheld
# 117 behind
# 54 behold
# 65 beings
# 23 belief
# 143 believe
# 53 believed
# 16 believing
# 20 bell
# 12 bells
# 12 belong
# 17 belonged
# 18 belonging
# 81 beloved
# 21 ben
# 11 bend
# 141 beneath
# 27 benefit
# 14 benevolence
# 15 benevolent
# 58 bent
# 11 berenice
# 10 berlifitzing
# 50 beside
# 62 besides
# 122 best
# 24 bestow
# 30 bestowed
# 12 betook
# 22 betrayed
# 150 better
# 10 betwixt
# 18 bewildered
# 260 beyond
# 9 bidding
# 50 big
# 15 bill
# 28 birch
# 18 bird
# 38 birds
# 42 birth
# 18 bishop
# 34 bit
# 10 bite
# 52 bitter
# 20 bitterly
# 20 bitterness
# 18 bizarre
# 198 black
# 11 blackened
# 27 blackness
# 10 blackwood
# 11 blanc
# 17 blank
# 17 blasphemous
# 16 blast
# 18 bleak
# 23 bless
# 15 blessed
# 12 blew
# 41 blind
# 15 bliss
# 11 block
# 17 blocks
# 117 blood
# 12 blossoms
# 21 blow
# 16 blows
# 77 blue
# 12 blush
# 48 board
# 13 boarded
# 89 boat
# 32 bob
# 55 bodies
# 27 bodily
# 228 body
# 20 bog
# 21 bold
# 13 boldly
# 21 bolt
# 10 bone
# 31 bones
# 85 book
# 84 books
# 73 bore
# 83 born
# 26 borne
# 49 bosom
# 18 boston
# 12 bottle
# 15 bottles
# 64 bottom
# 10 boughs
# 18 bought
# 42 bound
# 13 boundary
# 10 bounded
# 14 bounds
# 16 bow
# 13 bowed
# 11 bowl
# 87 box
# 71 boy
# 16 boyhood
# 19 boys
# 64 brain
# 13 brains
# 17 branch
# 31 branches
# 16 brass
# 12 brave
# 14 breadth
# 31 break
# 14 breakfast
# 19 breaking
# 31 breast
# 60 breath
# 14 breathe
# 26 breathed
# 33 breathing
# 13 breathless
# 16 bred
# 28 breeze
# 9 brewster
# 31 brick
# 10 bricks
# 11 bride
# 31 bridge
# 60 brief
# 44 bright
# 9 brighter
# 15 brilliancy
# 27 brilliant
# 76 bring
# 29 bringing
# 14 brings
# 20 brink
# 40 broad
# 42 broke
# 77 broken
# 9 bronze
# 9 brooded
# 11 brooding
# 60 brother
# 12 brothers
# 170 brought
# 45 brow
# 29 brown
# 9 brows
# 11 brute
# 29 bug
# 11 bugs
# 9 build
# 60 building
# 25 buildings
# 46 built
# 18 bulk
# 13 bullet
# 14 burden
# 11 burial
# 51 buried
# 17 burn
# 28 burned
# 45 burning
# 53 burst
# 13 bursting
# 17 burthen
# 19 bus
# 13 bushes
# 13 busied
# 77 business
# 37 busy
# 9 buy
# 10 bygone
# 27 cabin
# 21 calamity
# 14 calculated
# 110 call
# 173 called
# 29 calling
# 14 calls
# 78 calm
# 461 came
# 12 camp
# 27 candle
# 16 candles
# 182 cannot
# 18 canvas
# 19 cap
# 34 capable
# 18 capacity
# 10 cape
# 21 capital
# 50 captain
# 12 captured
# 59 car
# 103 care
# 25 career
# 19 careful
# 54 carefully
# 20 careless
# 10 carelessly
# 12 cares
# 15 carpet
# 19 carriage
# 57 carried
# 20 carry
# 30 carter
# 20 carved
# 16 carven
# 12 carvings
# 136 case
# 28 cases
# 91 cast
# 10 casting
# 66 castle
# 16 casual
# 28 cat
# 10 cataract
# 11 catastrophe
# 18 catch
# 20 cats
# 15 cattle
# 42 caught
# 102 cause
# 82 caused
# 15 causes
# 11 caution
# 14 cautious
# 11 cautiously
# 15 cavern
# 23 cease
# 60 ceased
# 19 ceiling
# 19 celebrated
# 12 celestial
# 18 cell
# 45 cellar
# 15 cemetery
# 18 central
# 41 centre
# 34 centuries
# 42 century
# 220 certain
# 71 certainly
# 14 certainty
# 9 cessation
# 21 chain
# 11 chains
# 47 chair
# 15 chairs
# 116 chamber
# 17 chambers
# 49 chance
# 10 chances
# 136 change
# 80 changed
# 30 changes
# 12 changing
# 20 channel
# 27 chaos
# 32 chapter
# 130 character
# 12 characteristic
# 10 characterized
# 40 characters
# 39 charge
# 9 charity
# 15 charles
# 10 charm
# 16 charnel
# 22 chasm
# 11 chateau
# 16 cheap
# 17 check
# 12 checked
# 30 cheek
# 25 cheeks
# 10 cheer
# 25 cheerful
# 12 chemical
# 15 cherished
# 35 chess
# 23 chest
# 43 chief
# 17 chiefly
# 126 child
# 23 childhood
# 20 childish
# 107 children
# 18 chill
# 14 chilled
# 29 chimney
# 16 chin
# 25 choice
# 20 choked
# 14 chose
# 21 chosen
# 39 church
# 14 churches
# 11 churchyard
# 33 circle
# 11 circles
# 11 circuit
# 22 circular
# 59 circumstance
# 104 circumstances
# 37 cities
# 17 citizens
# 226 city
# 16 clad
# 22 claim
# 15 claimed
# 11 clambered
# 37 clara
# 12 clasped
# 12 class
# 12 classes
# 14 claws
# 13 clean
# 80 clear
# 39 clearly
# 37 clerval
# 20 cliff
# 11 cliffs
# 20 climb
# 19 climbed
# 11 clinging
# 15 cloak
# 91 clock
# 132 close
# 79 closed
# 31 closely
# 29 closer
# 12 closet
# 20 closing
# 18 cloth
# 14 clothed
# 28 clothes
# 13 clothing
# 51 cloud
# 10 clouded
# 52 clouds
# 13 cloudy
# 9 club
# 24 clung
# 9 clutched
# 11 coach
# 13 coarse
# 30 coast
# 16 coat
# 35 coffin
# 11 coffins
# 15 cohort
# 13 coincidence
# 10 coincidences
# 112 cold
# 11 coldness
# 10 collect
# 29 collected
# 12 collecting
# 11 collection
# 42 college
# 29 color
# 14 colored
# 12 colossal
# 23 colour
# 21 colours
# 18 column
# 17 columns
# 12 combat
# 11 combination
# 9 combinations
# 13 combined
# 314 come
# 26 comes
# 16 comet
# 11 comfort
# 9 comfortable
# 85 coming
# 33 command
# 14 commanded
# 19 commence
# 38 commenced
# 15 commencement
# 9 comments
# 9 commerce
# 12 commercial
# 43 committed
# 92 common
# 13 communicated
# 16 communication
# 10 communications
# 10 community
# 78 companion
# 44 companions
# 12 companionship
# 74 company
# 17 comparatively
# 9 compare
# 13 compared
# 16 comparison
# 27 compartment
# 18 compassion
# 11 complained
# 47 complete
# 19 completed
# 36 completely
# 11 complex
# 13 complexion
# 12 comply
# 26 composed
# 18 composition
# 11 composure
# 10 compound
# 33 comprehend
# 9 comprehended
# 15 comprehension
# 20 conceal
# 36 concealed
# 16 concealment
# 9 conceivable
# 36 conceive
# 34 conceived
# 21 conception
# 13 concerned
# 59 concerning
# 26 concluded
# 41 conclusion
# 9 conclusions
# 11 condemned
# 9 condenser
# 69 condition
# 21 conditions
# 47 conduct
# 34 confess
# 29 confidence
# 25 confined
# 10 confinement
# 16 confirmed
# 13 confounded
# 21 confused
# 34 confusion
# 11 conjecture
# 12 conjectures
# 42 connected
# 12 connecting
# 14 connection
# 16 connexion
# 12 conquer
# 14 conquered
# 13 conscience
# 28 conscious
# 35 consciousness
# 25 consent
# 29 consequence
# 25 consequences
# 10 consequent
# 20 consequently
# 33 consider
# 29 considerable
# 14 considerably
# 32 consideration
# 18 considerations
# 67 considered
# 13 considering
# 16 consisted
# 27 consolation
# 12 console
# 10 conspicuous
# 22 constant
# 18 constantinople
# 22 constantly
# 14 constructed
# 10 contact
# 11 contagion
# 13 contain
# 27 contained
# 18 containing
# 12 contemplated
# 26 contemplation
# 26 contempt
# 34 content
# 10 contented
# 13 contention
# 26 contents
# 11 contest
# 10 continent
# 12 continual
# 22 continually
# 27 continue
# 145 continued
# 15 continuous
# 11 contour
# 28 contrary
# 14 contrast
# 24 contrived
# 13 control
# 11 convenient
# 65 conversation
# 14 converse
# 12 conversed
# 33 convey
# 19 conveyed
# 18 conviction
# 10 convince
# 36 convinced
# 10 convulsed
# 12 cool
# 22 copy
# 10 corey
# 11 corn
# 59 corner
# 99 corpse
# 11 corpses
# 10 corresponding
# 12 corruption
# 14 cosmic
# 10 cosmos
# 10 cost
# 10 cot
# 81 cottage
# 20 cottagers
# 10 cottages
# 10 cotton
# 18 couch
# 1316 could
# 16 count
# 15 counted
# 128 countenance
# 10 countenances
# 13 countess
# 158 country
# 14 countrymen
# 17 countryside
# 14 couple
# 66 courage
# 214 course
# 27 court
# 26 cousin
# 18 cover
# 69 covered
# 14 covering
# 17 crab
# 11 craving
# 12 crawled
# 16 creaking
# 17 create
# 23 created
# 39 creation
# 23 creator
# 69 creature
# 63 creatures
# 14 credit
# 20 crept
# 26 crew
# 72 cried
# 23 cries
# 39 crime
# 16 crimes
# 16 crimson
# 10 croaking
# 24 cross
# 41 crossed
# 16 crossing
# 52 crowd
# 33 crowded
# 20 crown
# 19 crowned
# 15 crude
# 21 cruel
# 10 cruelty
# 20 crumbling
# 11 crushed
# 37 cry
# 10 cryptic
# 17 cthulhu
# 12 cud
# 26 cult
# 15 cultivated
# 9 cumberland
# 12 cunning
# 17 cupboard
# 62 curiosity
# 62 curious
# 25 curiously
# 29 current
# 30 curse
# 25 cursed
# 9 curtain
# 15 curtains
# 9 curtis
# 20 custom
# 18 customary
# 10 customs
# 79 cut
# 13 cutting
# 10 cuttings
# 13 cyclopean
# 28 daemon
# 16 daemoniac
# 10 dagon
# 42 daily
# 11 damnable
# 13 damned
# 29 damp
# 12 dance
# 12 danced
# 17 dancing
# 68 danger
# 25 dangerous
# 14 dangers
# 13 dank
# 22 daown
# 58 dare
# 63 dared
# 223 dark
# 9 darkened
# 95 darkness
# 13 darted
# 15 dashed
# 27 dat
# 23 data
# 30 date
# 66 daughter
# 39 dawn
# 11 dawned
# 523 day
# 12 daylight
# 220 days
# 10 dazed
# 17 dazzling
# 154 de
# 203 dead
# 20 deadly
# 23 deal
# 134 dear
# 34 dearest
# 396 death
# 23 deaths
# 36 decay
# 13 decayed
# 13 decaying
# 21 deceased
# 10 deceit
# 20 deceived
# 14 decide
# 39 decided
# 15 decidedly
# 16 decision
# 10 decisive
# 27 deck
# 25 declared
# 15 declined
# 15 decomposition
# 9 decrepit
# 9 deductions
# 22 deed
# 11 deeds
# 19 deemed
# 191 deep
# 31 deeper
# 21 deepest
# 48 deeply
# 10 defeat
# 16 defence
# 14 define
# 12 defined
# 27 definite
# 12 degradation
# 9 degraded
# 102 degree
# 55 degrees
# 16 deity
# 30 delay
# 11 deliberate
# 11 delicacy
# 40 delicate
# 13 delicious
# 85 delight
# 19 delighted
# 9 delightful
# 9 delights
# 13 delirious
# 28 delirium
# 9 deliver
# 13 delivered
# 10 deluc
# 15 delusion
# 27 demand
# 25 demanded
# 10 demeanor
# 9 demeanour
# 16 demon
# 9 demonstration
# 16 den
# 15 denied
# 19 dense
# 22 deny
# 25 depart
# 53 departed
# 48 departure
# 10 depend
# 20 depended
# 10 deposes
# 9 deposit
# 23 deposited
# 16 depressed
# 23 deprived
# 29 depth
# 33 depths
# 14 derived
# 18 des
# 13 desart
# 24 descend
# 39 descended
# 17 descending
# 49 descent
# 56 describe
# 36 described
# 30 description
# 32 desert
# 70 deserted
# 9 desertion
# 18 deserved
# 74 design
# 13 designed
# 19 designs
# 78 desire
# 40 desired
# 19 desires
# 10 desirous
# 29 desolate
# 20 desolation
# 132 despair
# 17 desperate
# 12 desperately
# 52 despite
# 18 destined
# 30 destiny
# 28 destroy
# 56 destroyed
# 13 destroying
# 47 destruction
# 35 detail
# 18 detailed
# 36 details
# 25 determination
# 13 determine
# 59 determined
# 15 detestable
# 12 developed
# 12 development
# 10 devices
# 46 devil
# 14 devils
# 13 devote
# 32 devoted
# 19 devotion
# 16 dew
# 22 diameter
# 19 diana
# 17 diary
# 21 diddle
# 26 diddler
# 103 die
# 127 died
# 30 difference
# 66 different
# 42 difficult
# 11 difficulties
# 101 difficulty
# 10 digging
# 10 dignified
# 26 dignity
# 45 dim
# 12 dimensional
# 21 dimensions
# 19 diminished
# 11 dinner
# 11 dire
# 33 direct
# 35 directed
# 81 direction
# 21 directions
# 26 directly
# 12 dirty
# 16 disappearance
# 39 disappeared
# 11 disappointed
# 28 disappointment
# 14 disaster
# 10 disastrous
# 14 discern
# 10 discerned
# 12 discernible
# 27 discourse
# 42 discover
# 111 discovered
# 14 discoveries
# 65 discovery
# 18 discussed
# 21 discussion
# 14 disdain
# 55 disease
# 11 diseased
# 18 disgust
# 12 dislike
# 11 disliked
# 17 dismal
# 12 dismay
# 15 dismissed
# 29 disorder
# 12 disordered
# 16 display
# 20 displayed
# 12 disposed
# 44 disposition
# 13 dispositions
# 12 dispute
# 13 dissolution
# 104 distance
# 88 distant
# 53 distinct
# 16 distinction
# 25 distinctly
# 14 distinctness
# 25 distinguish
# 37 distinguished
# 21 distorted
# 15 distress
# 10 district
# 19 disturb
# 13 disturbance
# 41 disturbed
# 13 disturbing
# 16 divided
# 36 divine
# 11 division
# 10 dizzy
# 40 doctor
# 10 document
# 51 dog
# 32 dogs
# 9 doings
# 15 dollars
# 9 domes
# 15 dominion
# 145 done
# 14 doom
# 9 doomed
# 303 door
# 40 doors
# 15 doorway
# 21 double
# 9 doubled
# 19 doubly
# 159 doubt
# 14 doubted
# 17 doubtless
# 10 dow
# 17 downward
# 17 dozen
# 93 dr
# 16 drag
# 29 dragged
# 13 dragging
# 9 dragon
# 13 drama
# 14 drank
# 13 draperies
# 13 drapery
# 9 draught
# 27 draw
# 34 drawer
# 48 drawing
# 51 drawn
# 47 dread
# 37 dreaded
# 34 dreadful
# 145 dream
# 28 dreamed
# 9 dreamer
# 14 dreaming
# 150 dreams
# 20 dreary
# 42 dress
# 21 dressed
# 76 drew
# 13 drifted
# 11 drifting
# 24 drink
# 12 dripping
# 18 drive
# 30 driven
# 31 drop
# 36 dropped
# 12 dropping
# 22 drove
# 18 drowned
# 14 drug
# 9 drum
# 10 drunk
# 11 drunken
# 21 dry
# 12 du
# 10 duc
# 27 due
# 16 dug
# 14 duke
# 25 dull
# 18 dun
# 10 dungeon
# 26 dunwich
# 58 dupin
# 17 dusk
# 27 dust
# 14 dutch
# 31 duties
# 47 duty
# 25 dwell
# 42 dwelling
# 43 dwelt
# 54 dying
# 40 eager
# 19 eagerly
# 25 eagerness
# 39 ear
# 30 earl
# 13 earlier
# 9 earliest
# 91 early
# 35 earnest
# 13 earnestly
# 9 earnestness
# 73 ears
# 337 earth
# 21 earthly
# 13 earthquake
# 27 ease
# 80 easily
# 77 east
# 26 eastern
# 13 eastward
# 40 easy
# 9 eat
# 11 eaten
# 9 eating
# 17 ebony
# 16 echo
# 22 echoed
# 19 echoes
# 15 ecstasy
# 47 edge
# 10 edifice
# 11 edinburgh
# 29 editor
# 11 educated
# 13 education
# 19 ef
# 87 effect
# 21 effected
# 39 effects
# 52 effort
# 23 efforts
# 12 egress
# 18 eh
# 54 eight
# 13 eighteen
# 13 eighty
# 129 either
# 9 ejaculated
# 10 elaborate
# 29 elapsed
# 9 elbow
# 28 elder
# 10 eldest
# 10 election
# 27 electric
# 9 electricity
# 20 element
# 23 elements
# 10 eleonora
# 20 elevated
# 34 elevation
# 22 eleven
# 13 eliot
# 71 elizabeth
# 29 ellison
# 10 elopement
# 18 eloquence
# 9 eloquent
# 74 else
# 10 elsewhere
# 23 elwood
# 42 em
# 12 emaciated
# 11 embrace
# 11 embraced
# 12 emerged
# 9 eminence
# 11 eminent
# 31 emotion
# 31 emotions
# 11 empire
# 19 employ
# 46 employed
# 14 employment
# 37 empty
# 17 en
# 12 enable
# 32 enabled
# 9 enchanted
# 9 enclosure
# 12 encompassed
# 14 encounter
# 26 encountered
# 211 end
# 17 endeavor
# 21 endeavored
# 28 endeavour
# 52 endeavoured
# 17 endeavouring
# 9 endeavours
# 26 ended
# 17 endless
# 14 ends
# 27 endure
# 35 endured
# 11 enduring
# 20 enemies
# 48 enemy
# 13 energetic
# 45 energy
# 40 engaged
# 10 engine
# 118 england
# 66 english
# 26 enjoy
# 30 enjoyed
# 10 enjoying
# 27 enjoyment
# 10 enlightened
# 20 enormous
# 122 enough
# 13 ensued
# 56 enter
# 145 entered
# 29 entering
# 10 enterprise
# 13 entertain
# 22 entertained
# 45 enthusiasm
# 14 enthusiastic
# 73 entire
# 91 entirely
# 14 entitled
# 15 entity
# 30 entrance
# 18 entreat
# 10 entreaties
# 21 enveloped
# 11 envy
# 24 epoch
# 45 equal
# 29 equally
# 20 ere
# 15 erect
# 10 ernest
# 19 error
# 10 errors
# 85 escape
# 39 escaped
# 11 escaping
# 17 espanaye
# 20 especial
# 88 especially
# 13 essence
# 19 est
# 17 established
# 18 estate
# 24 et
# 28 eternal
# 13 eternity
# 14 ether
# 12 ethereal
# 23 etoile
# 11 eugenie
# 14 europe
# 11 eustache
# 40 evadne
# 17 eve
# 701 even
# 122 evening
# 48 event
# 78 events
# 408 ever
# 535 every
# 12 everybody
# 12 everyone
# 36 everything
# 11 everywhere
# 61 evidence
# 56 evident
# 69 evidently
# 126 evil
# 17 evils
# 10 evinced
# 11 ex
# 26 exact
# 27 exactly
# 17 exalted
# 25 examination
# 20 examine
# 25 examined
# 12 examining
# 52 example
# 14 exceeding
# 62 exceedingly
# 20 excellence
# 14 excellencies
# 47 excellent
# 65 except
# 26 exception
# 31 excess
# 23 excessive
# 21 excessively
# 12 exchange
# 14 exchanged
# 78 excited
# 41 excitement
# 14 exciting
# 38 exclaimed
# 12 excuse
# 13 executed
# 20 execution
# 23 exercise
# 11 exercised
# 15 exerted
# 32 exertion
# 20 exertions
# 22 exhausted
# 18 exhibited
# 18 exhibition
# 10 exile
# 38 exist
# 38 existed
# 117 existence
# 15 existing
# 11 exotic
# 31 expect
# 34 expectation
# 70 expected
# 10 expedient
# 17 expedition
# 46 experience
# 48 experienced
# 11 experiences
# 25 experiment
# 16 experiments
# 30 explain
# 17 explained
# 36 explanation
# 11 explore
# 12 exposed
# 30 express
# 47 expressed
# 111 expression
# 26 expressions
# 10 expressive
# 26 exquisite
# 11 exquisitely
# 27 extended
# 14 extending
# 16 extensive
# 69 extent
# 15 external
# 14 extinct
# 16 extinguished
# 10 extra
# 42 extraordinary
# 71 extreme
# 12 extremely
# 23 extremity
# 11 exultation
# 167 eye
# 21 eyed
# 10 eyelids
# 540 eyes
# 11 fabric
# 13 fabulous
# 212 face
# 13 faced
# 54 faces
# 159 fact
# 11 factory
# 26 facts
# 11 faculties
# 11 fade
# 21 faded
# 42 fail
# 55 failed
# 14 failing
# 19 failure
# 74 faint
# 9 fainting
# 17 faintly
# 62 fair
# 36 fairly
# 12 fairy
# 25 faith
# 13 faithful
# 67 fall
# 76 fallen
# 36 falling
# 19 falls
# 28 false
# 12 falsehood
# 18 fame
# 56 familiar
# 15 families
# 137 family
# 16 famine
# 46 fancied
# 22 fancies
# 15 fanciful
# 84 fancy
# 10 fancying
# 10 fangs
# 34 fantastic
# 376 far
# 44 farewell
# 17 farmhouse
# 55 farther
# 16 farthest
# 11 fascination
# 49 fashion
# 18 fashioned
# 23 fast
# 22 fastened
# 18 fat
# 25 fatal
# 79 fate
# 267 father
# 18 fathers
# 14 fatigue
# 13 fault
# 21 favour
# 10 favourable
# 34 favourite
# 241 fear
# 56 feared
# 62 fearful
# 17 fearfully
# 10 fearing
# 59 fears
# 15 feature
# 60 features
# 13 fed
# 53 feeble
# 164 feel
# 115 feeling
# 116 feelings
# 14 feels
# 190 feet
# 44 felix
# 157 fell
# 112 fellow
# 21 fellows
# 343 felt
# 25 female
# 24 fer
# 17 fertile
# 16 festival
# 52 fever
# 15 feverish
# 44 field
# 42 fields
# 40 fiend
# 15 fiendish
# 18 fierce
# 12 fiery
# 28 fifteen
# 16 fifth
# 45 fifty
# 16 fight
# 88 figure
# 38 figures
# 17 fill
# 110 filled
# 10 filling
# 10 filthy
# 38 final
# 93 finally
# 225 find
# 46 finding
# 13 finds
# 65 fine
# 16 finger
# 32 fingers
# 29 finished
# 109 fire
# 10 fired
# 14 fireplace
# 16 fires
# 38 firm
# 16 firmly
# 602 first
# 35 fish
# 9 fishermen
# 13 fishing
# 10 fishy
# 43 fit
# 26 fitted
# 14 fitting
# 127 five
# 50 fixed
# 33 flame
# 24 flames
# 22 flash
# 13 flashed
# 9 flashes
# 14 flashlight
# 15 flat
# 53 fled
# 30 flesh
# 19 flew
# 12 flies
# 28 flight
# 9 flitted
# 31 floated
# 20 floating
# 10 flock
# 17 flood
# 137 floor
# 14 floors
# 20 flow
# 22 flowed
# 30 flower
# 59 flowers
# 12 flowing
# 15 flung
# 43 fly
# 22 flying
# 10 foe
# 13 folded
# 14 folding
# 15 folds
# 18 foliage
# 36 folk
# 40 folks
# 52 follow
# 104 followed
# 59 following
# 15 follows
# 31 folly
# 14 fond
# 50 food
# 27 fool
# 12 foolish
# 10 fools
# 62 foot
# 23 footsteps
# 32 forbidden
# 83 force
# 54 forced
# 19 forces
# 31 forehead
# 27 foreign
# 63 forest
# 61 forever
# 42 forget
# 18 forgot
# 75 forgotten
# 187 form
# 100 formed
# 83 former
# 22 formerly
# 22 forming
# 62 forms
# 10 formulae
# 106 forth
# 25 forthwith
# 13 fortitude
# 11 fortnight
# 11 fortunately
# 10 fortunato
# 46 fortune
# 37 forty
# 50 forward
# 10 fought
# 559 found
# 16 foundations
# 17 founded
# 114 four
# 38 fourth
# 11 fragment
# 23 fragments
# 13 frail
# 74 frame
# 17 france
# 10 francs
# 16 frank
# 19 frankenstein
# 34 frantic
# 16 frantically
# 70 free
# 27 freedom
# 21 freely
# 35 french
# 17 frenchman
# 14 frenzy
# 47 frequent
# 43 frequently
# 71 fresh
# 275 friend
# 110 friends
# 35 friendship
# 33 fright
# 36 frightened
# 61 frightful
# 25 fro
# 47 front
# 10 frost
# 16 frozen
# 10 fruit
# 13 fruits
# 9 frye
# 21 fulfilled
# 16 fulfilment
# 226 full
# 12 fullest
# 86 fully
# 9 fumes
# 11 functions
# 18 funeral
# 9 fur
# 15 furious
# 11 furiously
# 31 furniture
# 11 furry
# 19 furtive
# 43 fury
# 13 futile
# 74 future
# 15 gaiety
# 28 gain
# 27 gained
# 11 gait
# 15 gale
# 10 gallant
# 9 gambrel
# 44 game
# 18 gang
# 10 garb
# 32 garden
# 32 gardens
# 23 garret
# 27 gas
# 13 gasped
# 48 gate
# 18 gates
# 15 gather
# 29 gathered
# 17 gathering
# 238 gave
# 13 gawd
# 35 gay
# 27 gaze
# 54 gazed
# 14 gazette
# 24 gazing
# 158 general
# 39 generally
# 10 generation
# 11 generations
# 24 generous
# 27 geneva
# 55 genius
# 112 gentle
# 72 gentleman
# 32 gentlemen
# 17 gentleness
# 33 gently
# 10 genuine
# 14 george
# 28 german
# 18 gesture
# 17 gestures
# 117 get
# 44 getting
# 52 ghastly
# 17 ghost
# 10 ghoulish
# 21 giant
# 15 gift
# 53 gigantic
# 12 gilded
# 76 gilman
# 86 girl
# 21 git
# 148 give
# 127 given
# 20 gives
# 47 giving
# 39 glad
# 55 glance
# 15 glanced
# 11 glancing
# 25 glare
# 11 glaring
# 58 glass
# 11 glasses
# 12 glassy
# 11 gleamed
# 17 gleaming
# 18 glen
# 10 glided
# 35 glimpse
# 17 glimpsed
# 12 glistened
# 11 glittering
# 20 globe
# 38 gloom
# 32 gloomy
# 33 glorious
# 48 glory
# 29 glow
# 20 glowing
# 193 go
# 10 goal
# 140 god
# 12 goddess
# 70 gods
# 19 goes
# 75 going
# 71 gold
# 59 golden
# 121 gone
# 277 good
# 14 goodness
# 13 goosetherumfoodle
# 11 gorge
# 13 gorgeous
# 79 got
# 13 gothic
# 28 government
# 46 grace
# 34 graceful
# 12 gradual
# 52 gradually
# 18 grand
# 11 grandeur
# 24 grandfather
# 18 grandmother
# 18 granite
# 12 grant
# 14 granted
# 28 grasp
# 12 grasped
# 47 grass
# 9 grassy
# 15 grateful
# 24 gratitude
# 98 grave
# 14 graves
# 12 gravity
# 14 gray
# 512 great
# 103 greater
# 65 greatest
# 48 greatly
# 9 grecian
# 47 greece
# 51 greek
# 19 greeks
# 102 green
# 9 greenish
# 146 grew
# 60 grey
# 90 grief
# 11 grieved
# 15 grim
# 9 grin
# 15 grinning
# 9 groan
# 35 grotesque
# 130 ground
# 19 grounds
# 21 group
# 9 groups
# 18 grove
# 19 groves
# 30 grow
# 35 growing
# 50 grown
# 13 grows
# 19 growth
# 10 gruesome
# 10 gruff
# 19 guard
# 13 guarded
# 13 guardian
# 42 guess
# 10 guessed
# 14 guest
# 15 guests
# 35 guide
# 21 guided
# 21 guilt
# 18 guilty
# 18 gulf
# 10 gulfs
# 9 gum
# 10 gush
# 9 guttural
# 38 ha
# 31 habit
# 15 habitation
# 28 habits
# 12 habitual
# 9 habitually
# 9 haff
# 10 hail
# 13 hailed
# 88 hair
# 262 half
# 51 hall
# 14 halls
# 10 hamlet
# 292 hand
# 22 handed
# 13 handkerchief
# 159 hands
# 10 handsome
# 15 hanging
# 9 hans
# 10 haouse
# 11 haow
# 13 happen
# 52 happened
# 10 happens
# 10 happier
# 120 happiness
# 119 happy
# 9 harassed
# 27 harbour
# 57 hard
# 72 hardly
# 13 harmless
# 14 harmony
# 24 harris
# 17 harsh
# 23 haste
# 17 hasten
# 28 hastened
# 17 hastily
# 13 hat
# 33 hate
# 18 hated
# 15 hateful
# 15 hath
# 17 hatheg
# 25 hatred
# 12 haughty
# 12 haunt
# 46 haunted
# 300 head
# 18 headed
# 10 headlong
# 27 heads
# 72 health
# 105 hear
# 366 heard
# 30 hearing
# 375 heart
# 11 hearted
# 33 hearts
# 25 heat
# 14 heath
# 110 heaven
# 13 heavenly
# 49 heavens
# 30 heavily
# 91 heavy
# 19 heerd
# 25 heh
# 70 height
# 12 heightened
# 13 heir
# 114 held
# 26 hell
# 29 hellish
# 65 help
# 12 helped
# 15 helpless
# 18 hence
# 22 henry
# 14 herbert
# 15 hereafter
# 12 hereditary
# 9 hermit
# 18 hero
# 12 hesitate
# 15 hesitated
# 20 hesitation
# 9 heterogeneous
# 9 hey
# 24 hid
# 54 hidden
# 13 hide
# 119 hideous
# 15 hideously
# 12 hiding
# 205 high
# 46 higher
# 27 highest
# 34 highly
# 9 highway
# 89 hill
# 83 hills
# 17 hillside
# 32 hint
# 13 hinted
# 12 hints
# 14 hired
# 50 history
# 12 hither
# 50 hitherto
# 11 hoary
# 85 hold
# 23 holding
# 13 holds
# 38 hole
# 11 holes
# 13 holland
# 33 hollow
# 22 holy
# 169 home
# 12 honest
# 20 honor
# 40 honour
# 9 hoop
# 195 hope
# 29 hoped
# 13 hopeless
# 79 hopes
# 54 horizon
# 82 horrible
# 17 horribly
# 9 horrid
# 198 horror
# 37 horrors
# 46 horse
# 28 horses
# 15 hospital
# 42 host
# 19 hot
# 27 hotel
# 165 hour
# 12 hourly
# 172 hours
# 366 house
# 11 household
# 99 houses
# 11 hovel
# 17 hovered
# 358 however
# 10 howling
# 10 hu
# 25 hue
# 12 hues
# 63 huge
# 13 hum
# 274 human
# 36 humanity
# 12 humble
# 11 humour
# 81 hundred
# 71 hung
# 16 hunger
# 32 hurried
# 11 hurriedly
# 14 hurry
# 14 hurt
# 35 husband
# 18 hushed
# 16 hut
# 67 ice
# 195 idea
# 57 ideas
# 11 identical
# 10 identify
# 24 identity
# 15 idle
# 19 idol
# 109 idris
# 23 ignorance
# 31 ignorant
# 10 il
# 89 ill
# 17 illness
# 24 illustrious
# 52 image
# 27 images
# 106 imagination
# 11 imaginative
# 53 imagine
# 44 imagined
# 9 imagining
# 12 imbued
# 13 imitation
# 68 immediate
# 120 immediately
# 10 immemorial
# 37 immense
# 14 immortal
# 9 immortality
# 21 impatience
# 19 impatient
# 11 impeded
# 9 impending
# 12 imperfect
# 11 impetuous
# 26 importance
# 33 important
# 99 impossible
# 12 impress
# 28 impressed
# 50 impression
# 36 impressions
# 11 imprisoned
# 16 improvement
# 36 impulse
# 16 impulses
# 13 inability
# 11 inanimate
# 19 incapable
# 19 inch
# 45 inches
# 15 incident
# 13 incidents
# 26 inclined
# 14 including
# 12 incoherent
# 10 incomprehensible
# 22 inconceivable
# 13 inconvenience
# 30 increase
# 58 increased
# 22 increasing
# 17 incredible
# 316 indeed
# 16 indefinite
# 17 indescribable
# 12 india
# 12 indian
# 10 indians
# 14 indignation
# 15 indistinct
# 52 individual
# 12 individuals
# 11 induce
# 32 induced
# 12 indulged
# 14 inevitable
# 13 inevitably
# 11 inexplicable
# 16 infancy
# 20 infant
# 11 infected
# 11 infection
# 10 inferior
# 28 infinite
# 17 infinitely
# 17 infinity
# 9 infirmity
# 12 inflicted
# 81 influence
# 11 influenced
# 40 information
# 18 informed
# 18 ingenious
# 20 ingenuity
# 13 ingolstadt
# 9 inhabit
# 51 inhabitants
# 25 inhabited
# 9 inherited
# 10 inhuman
# 11 injected
# 20 injury
# 16 inn
# 21 inner
# 22 innocence
# 26 innocent
# 60 innsmouth
# 27 innumerable
# 14 inquired
# 26 inquiries
# 17 inquiry
# 16 insane
# 16 insanity
# 9 inserted
# 24 inside
# 11 insist
# 19 insisted
# 9 inspection
# 11 inspector
# 14 inspire
# 34 inspired
# 42 instance
# 14 instances
# 85 instant
# 38 instantly
# 48 instead
# 16 instinct
# 11 instinctively
# 10 instructed
# 18 instrument
# 30 instruments
# 13 insult
# 37 intellect
# 18 intellectual
# 37 intelligence
# 16 intelligent
# 11 intend
# 34 intended
# 61 intense
# 29 intensity
# 9 intent
# 20 intention
# 12 intentions
# 22 intercourse
# 119 interest
# 34 interested
# 20 interesting
# 10 interests
# 10 interference
# 40 interior
# 29 interrupted
# 36 interval
# 37 intervals
# 13 intervening
# 12 intimate
# 24 intolerable
# 21 introduced
# 15 introduction
# 18 invention
# 29 investigation
# 17 investigations
# 17 invisible
# 16 involved
# 10 inward
# 26 iranon
# 10 irish
# 13 irksome
# 51 iron
# 14 irregular
# 63 island
# 21 islands
# 13 isolated
# 12 issued
# 25 italian
# 12 italy
# 10 item
# 19 ivory
# 10 jealousy
# 13 jenkin
# 43 jermyn
# 19 jest
# 10 jewels
# 22 joe
# 23 johansen
# 39 john
# 26 join
# 47 joined
# 20 journal
# 59 journey
# 101 joy
# 21 judge
# 15 judged
# 13 judgment
# 15 july
# 23 june
# 45 jupiter
# 24 justice
# 42 justine
# 11 justly
# 17 kalos
# 10 kate
# 15 keen
# 74 keep
# 24 keeping
# 15 kempelen
# 90 kept
# 57 key
# 15 keziah
# 12 kilderry
# 14 kill
# 22 killed
# 16 kin
# 185 kind
# 10 kinder
# 12 kindly
# 37 kindness
# 12 kinds
# 61 king
# 13 kingdom
# 15 kings
# 25 kingsport
# 9 kirwin
# 13 kissed
# 11 kla
# 14 klenze
# 21 knees
# 273 knew
# 11 knife
# 11 knock
# 24 knocked
# 9 knocking
# 10 knot
# 337 know
# 32 knowing
# 110 knowledge
# 186 known
# 33 knows
# 14 kuranes
# 25 la
# 18 labor
# 28 laboratory
# 30 labour
# 9 labourers
# 32 labours
# 10 lack
# 11 ladies
# 108 lady
# 39 laid
# 10 lain
# 52 lake
# 27 lalande
# 9 lament
# 31 lamp
# 118 land
# 19 landed
# 9 landing
# 10 landlady
# 9 landlord
# 18 lands
# 25 landscape
# 11 lane
# 11 lanes
# 62 language
# 12 languages
# 17 lantern
# 14 lapse
# 156 large
# 13 largely
# 21 larger
# 338 last
# 12 latch
# 110 late
# 34 lately
# 83 later
# 20 latin
# 116 latter
# 25 laugh
# 31 laughed
# 19 laughing
# 26 laughter
# 25 law
# 9 lawless
# 48 laws
# 216 lay
# 46 le
# 51 lead
# 9 leaden
# 15 leader
# 46 leading
# 11 leads
# 18 lean
# 18 leaned
# 21 leaning
# 19 leaped
# 10 leaping
# 30 learn
# 55 learned
# 11 learning
# 14 learnt
# 184 least
# 108 leave
# 45 leaves
# 57 leaving
# 122 led
# 11 lee
# 354 left
# 20 legend
# 25 legends
# 27 legrand
# 17 legrasse
# 36 legs
# 12 leisure
# 278 length
# 9 lent
# 250 less
# 10 lesser
# 11 lesson
# 12 lessons
# 30 lest
# 298 let
# 100 letter
# 48 letters
# 9 letting
# 37 level
# 24 liberty
# 30 library
# 13 lid
# 20 lids
# 42 lie
# 32 lies
# 569 life
# 19 lifeless
# 10 lift
# 21 lifted
# 15 ligeia
# 320 light
# 23 lighted
# 12 lighter
# 12 lightly
# 39 lightning
# 41 lights
# 613 like
# 19 likely
# 12 likewise
# 23 limb
# 51 limbs
# 16 limit
# 10 limited
# 11 limitless
# 18 limits
# 92 line
# 40 lines
# 15 lingered
# 16 link
# 15 linked
# 22 lionel
# 102 lips
# 15 liquid
# 14 list
# 47 listen
# 60 listened
# 25 listening
# 19 lit
# 12 literary
# 531 little
# 92 live
# 89 lived
# 12 lively
# 40 lives
# 13 livid
# 107 living
# 24 loathsome
# 24 local
# 19 locality
# 21 lock
# 29 locked
# 10 loft
# 38 lofty
# 12 logical
# 24 lollipop
# 87 london
# 16 lone
# 29 lonely
# 511 long
# 20 longed
# 152 longer
# 181 look
# 231 looked
# 133 looking
# 43 looks
# 34 loose
# 10 loosened
# 78 lord
# 21 lore
# 27 lose
# 11 losing
# 44 loss
# 181 lost
# 30 lot
# 41 loud
# 30 louder
# 11 loudly
# 332 love
# 99 loved
# 29 loveliness
# 83 lovely
# 28 lover
# 9 loves
# 13 loving
# 132 low
# 50 lower
# 11 lowly
# 20 luminous
# 9 lungs
# 9 lurked
# 18 lurking
# 24 lustre
# 20 luxury
# 34 lying
# 72 machine
# 32 machinery
# 94 mad
# 77 madame
# 13 maddening
# 565 made
# 15 mademoiselle
# 17 madly
# 21 madman
# 71 madness
# 29 maelzel
# 9 magazine
# 31 magic
# 9 magician
# 13 magistrate
# 11 magnificence
# 37 magnificent
# 11 magnitude
# 13 maiden
# 11 maillard
# 79 main
# 26 maintained
# 17 majestic
# 26 majesty
# 12 major
# 280 make
# 39 makes
# 76 making
# 13 malady
# 10 malignity
# 779 man
# 17 managed
# 10 mangled
# 11 maniac
# 13 manifest
# 49 mankind
# 177 manner
# 27 manners
# 48 mansion
# 10 manton
# 17 manuscript
# 491 many
# 12 map
# 62 marble
# 25 march
# 10 margaret
# 50 marie
# 34 mark
# 53 marked
# 11 market
# 13 marks
# 30 marriage
# 26 married
# 11 marry
# 27 marsh
# 24 martense
# 17 marvellous
# 16 mask
# 15 mason
# 15 masonry
# 29 mass
# 22 massa
# 15 masses
# 10 massive
# 42 master
# 16 match
# 13 mate
# 56 material
# 11 materially
# 14 materials
# 18 mathematical
# 13 mathematics
# 11 mathilda
# 187 matter
# 40 matters
# 16 maturity
# 442 may
# 9 maybe
# 13 mazurewicz
# 10 meadow
# 10 meadows
# 9 meal
# 74 mean
# 48 meaning
# 168 means
# 30 meant
# 51 meantime
# 29 meanwhile
# 42 measure
# 11 measured
# 14 measures
# 14 mechanical
# 30 mechanism
# 26 medical
# 12 medicine
# 17 meditation
# 18 medium
# 57 meet
# 28 meeting
# 64 melancholy
# 17 melody
# 10 melted
# 17 member
# 21 members
# 11 memorable
# 30 memories
# 110 memory
# 363 men
# 12 menace
# 51 mental
# 30 mention
# 72 mentioned
# 15 merchant
# 13 merciful
# 16 mercy
# 118 mere
# 113 merely
# 20 merit
# 12 merits
# 10 merrival
# 12 merry
# 13 mesmeric
# 16 message
# 9 messenger
# 12 messrs
# 89 met
# 24 metal
# 24 method
# 12 methought
# 14 metropolis
# 15 metzengerstein
# 10 mid
# 42 middle
# 59 midnight
# 28 midst
# 14 mien
# 629 might
# 55 mighty
# 12 mild
# 19 mile
# 63 miles
# 13 military
# 14 mill
# 17 mille
# 11 million
# 12 millions
# 378 mind
# 13 minded
# 23 minds
# 95 mine
# 9 mingle
# 38 mingled
# 12 miniature
# 19 minister
# 57 minute
# 10 minutely
# 9 minuteness
# 84 minutes
# 12 miraculous
# 33 mirror
# 10 mischief
# 76 miserable
# 12 miseries
# 105 misery
# 20 misfortune
# 22 misfortunes
# 25 miskatonic
# 20 miss
# 12 missing
# 27 mist
# 22 mistake
# 32 mistaken
# 9 mistress
# 24 mists
# 12 misty
# 26 mixed
# 17 mixture
# 11 mnar
# 17 mockery
# 13 mocking
# 40 mode
# 18 model
# 13 moderate
# 40 modern
# 12 modes
# 11 moissart
# 259 moment
# 12 momentary
# 49 moments
# 11 mon
# 9 monarch
# 10 monday
# 49 money
# 15 monotonous
# 39 monsieur
# 42 monster
# 10 monsters
# 9 monstrosity
# 50 monstrous
# 10 mont
# 44 month
# 101 months
# 13 mood
# 11 moods
# 179 moon
# 22 moonlight
# 10 moor
# 32 moral
# 26 morbid
# 9 morbidity
# 13 morella
# 22 moreover
# 11 morgan
# 12 morgue
# 177 morning
# 40 morrow
# 47 mortal
# 12 mortality
# 15 moskoe
# 15 moss
# 17 mostly
# 151 mother
# 76 motion
# 10 motioned
# 23 motionless
# 35 motions
# 23 motive
# 12 motives
# 20 mould
# 9 moulded
# 9 mouldy
# 14 mound
# 94 mountain
# 10 mountainous
# 67 mountains
# 11 mounted
# 14 mournful
# 66 mouth
# 55 move
# 67 moved
# 29 movement
# 19 movements
# 12 moves
# 24 moving
# 206 mr
# 31 mrs
# 10 ms
# 459 much
# 19 mud
# 17 muffled
# 35 multitude
# 57 murder
# 15 murdered
# 29 murderer
# 10 murderers
# 18 murmur
# 10 muscles
# 14 museum
# 71 music
# 18 musical
# 19 musides
# 594 must
# 16 mute
# 12 muttered
# 15 mutual
# 9 myriad
# 20 mysteries
# 28 mysterious
# 56 mystery
# 11 mystic
# 12 nail
# 12 naked
# 184 name
# 24 named
# 40 nameless
# 33 names
# 11 naow
# 11 narration
# 16 narrative
# 77 narrow
# 12 nation
# 13 nations
# 71 native
# 22 natives
# 115 natural
# 30 naturally
# 286 nature
# 22 nay
# 10 nd
# 228 near
# 33 nearer
# 30 nearest
# 168 nearly
# 21 necessarily
# 100 necessary
# 46 necessity
# 42 neck
# 16 necronomicon
# 62 need
# 17 needed
# 13 needless
# 10 needs
# 18 neglect
# 34 neglected
# 18 negro
# 10 neighborhood
# 16 neighbourhood
# 24 neighbouring
# 10 neighbours
# 108 neither
# 18 nerve
# 28 nerves
# 47 nervous
# 9 nervously
# 570 never
# 40 nevertheless
# 262 new
# 15 newly
# 19 news
# 12 newspaper
# 13 newspapers
# 129 next
# 9 nice
# 14 nigh
# 566 night
# 9 nightly
# 27 nightmare
# 20 nights
# 39 nine
# 9 nineteenth
# 9 nitre
# 10 nobility
# 55 noble
# 10 nobleman
# 33 nobody
# 14 nocturnal
# 39 noise
# 20 noises
# 10 noisome
# 26 non
# 128 none
# 34 noon
# 19 normal
# 87 north
# 26 northern
# 12 northward
# 56 nose
# 34 note
# 17 noted
# 40 notes
# 9 nothin
# 299 nothing
# 10 nothingness
# 54 notice
# 46 noticed
# 16 notion
# 13 notions
# 23 notwithstanding
# 10 nought
# 21 novel
# 12 november
# 10 noxious
# 66 number
# 29 numbers
# 33 numerous
# 20 nurse
# 15 nursed
# 18 oak
# 11 oath
# 12 ob
# 29 obed
# 10 obeyed
# 165 object
# 69 objects
# 37 obliged
# 35 obscure
# 42 observation
# 22 observations
# 35 observe
# 109 observed
# 12 observer
# 22 observing
# 10 obstacle
# 27 obtain
# 58 obtained
# 37 obvious
# 19 obviously
# 51 occasion
# 19 occasional
# 29 occasionally
# 41 occasioned
# 14 occasions
# 16 occupation
# 25 occupations
# 60 occupied
# 12 occupy
# 16 occur
# 70 occurred
# 18 occurrence
# 10 occurrences
# 75 ocean
# 21 october
# 88 odd
# 22 oddly
# 21 odour
# 24 offer
# 35 offered
# 12 offering
# 32 office
# 14 officer
# 20 officers
# 17 offspring
# 178 often
# 126 oh
# 26 oil
# 616 old
# 12 olden
# 34 older
# 15 olive
# 12 olney
# 15 ominous
# 1623 one
# 53 ones
# 15 onward
# 11 oonai
# 203 open
# 96 opened
# 46 opening
# 11 openly
# 15 opens
# 16 operation
# 24 operations
# 54 opinion
# 29 opinions
# 20 oppodeldoc
# 28 opportunity
# 41 opposite
# 12 opposition
# 24 oppressed
# 10 oppressive
# 13 orange
# 15 orb
# 89 order
# 20 ordered
# 13 orders
# 83 ordinary
# 12 organ
# 23 organic
# 14 organs
# 36 origin
# 62 original
# 19 originally
# 9 orphan
# 142 others
# 47 otherwise
# 44 ought
# 12 ourang
# 11 outang
# 12 outer
# 13 outline
# 14 outlines
# 14 outrage
# 72 outside
# 12 outstretched
# 21 outward
# 11 overboard
# 32 overcome
# 13 overflowing
# 26 overhead
# 9 overlooked
# 9 overwhelmed
# 13 overwhelming
# 16 owner
# 11 pace
# 22 page
# 20 pages
# 37 paid
# 80 pain
# 46 painful
# 19 pains
# 12 paint
# 29 painted
# 15 painter
# 14 painting
# 12 paintings
# 29 pair
# 51 palace
# 17 palaces
# 70 pale
# 12 pallid
# 11 palpable
# 10 pandemonium
# 11 paned
# 19 panes
# 18 panic
# 10 panting
# 86 paper
# 37 papers
# 23 paradise
# 16 paragraph
# 12 parallel
# 25 parchment
# 30 pardon
# 14 parent
# 32 parents
# 46 paris
# 10 parisian
# 19 park
# 260 part
# 13 partial
# 19 partially
# 53 particular
# 23 particularly
# 20 particulars
# 45 partly
# 10 partook
# 33 parts
# 80 party
# 64 pass
# 70 passage
# 20 passages
# 219 passed
# 16 passengers
# 15 passes
# 46 passing
# 74 passion
# 31 passionate
# 12 passionately
# 35 passions
# 133 past
# 11 paternal
# 66 path
# 15 paths
# 17 patience
# 37 patient
# 39 pause
# 49 paused
# 12 pausing
# 10 pavement
# 34 pay
# 64 peace
# 11 peaceful
# 17 peak
# 14 peaked
# 12 peaks
# 16 peasant
# 13 peasants
# 101 peculiar
# 11 peculiarities
# 17 peculiarity
# 22 peculiarly
# 12 peer
# 18 pen
# 10 pencil
# 9 pendulum
# 18 penetrate
# 10 penetrated
# 164 people
# 27 per
# 68 perceive
# 74 perceived
# 22 perceiving
# 23 perceptible
# 16 perception
# 169 perdita
# 60 perfect
# 12 perfection
# 36 perfectly
# 14 perform
# 26 performed
# 203 perhaps
# 20 peril
# 11 perilous
# 136 period
# 12 periods
# 13 perish
# 15 perished
# 11 permanent
# 9 permission
# 24 permit
# 49 permitted
# 23 perpetual
# 19 perpetually
# 10 perplexed
# 9 perseverance
# 160 person
# 15 personage
# 46 personal
# 62 persons
# 12 persuade
# 21 persuaded
# 15 persuasion
# 13 perusal
# 10 pervaded
# 9 pervading
# 17 pest
# 33 pestilence
# 13 phenomena
# 17 phenomenon
# 11 philosophers
# 38 philosophy
# 19 phrase
# 53 physical
# 32 physician
# 16 physicians
# 20 picked
# 28 pickman
# 51 picture
# 15 pictured
# 19 pictures
# 11 picturesque
# 53 piece
# 25 pieces
# 11 piercing
# 20 pile
# 14 piled
# 16 pillars
# 15 pillow
# 15 piping
# 24 pit
# 15 pitch
# 12 pitiful
# 26 pity
# 340 place
# 89 placed
# 61 places
# 24 placid
# 15 placing
# 83 plague
# 63 plain
# 27 plainly
# 21 plains
# 48 plan
# 14 plane
# 19 planet
# 10 planets
# 11 planned
# 36 plans
# 10 plaster
# 41 play
# 35 played
# 32 player
# 26 playing
# 30 pleasant
# 25 please
# 28 pleased
# 13 pleasing
# 86 pleasure
# 16 pleasures
# 17 plenty
# 22 plunge
# 22 plunged
# 54 pocket
# 9 pockets
# 11 poem
# 33 poet
# 15 poetic
# 16 poets
# 200 point
# 35 pointed
# 12 pointing
# 47 points
# 19 poison
# 10 poisoned
# 17 pole
# 48 police
# 14 political
# 22 pompey
# 10 pondered
# 14 ponderous
# 10 pool
# 137 poor
# 10 populace
# 13 popular
# 16 population
# 13 port
# 105 portion
# 11 portions
# 15 portrait
# 85 position
# 29 positive
# 22 positively
# 32 possess
# 91 possessed
# 53 possession
# 10 possessor
# 19 possibility
# 143 possible
# 35 possibly
# 21 post
# 17 pot
# 16 pounds
# 11 pour
# 28 poured
# 14 pouring
# 29 poverty
# 10 powder
# 169 power
# 30 powerful
# 53 powers
# 22 practical
# 25 practice
# 15 praise
# 15 pray
# 10 prayed
# 11 prayer
# 14 prayers
# 11 precaution
# 13 preceding
# 9 precincts
# 13 precious
# 13 precipice
# 10 precipitate
# 10 precipitated
# 11 precipitous
# 22 precise
# 43 precisely
# 28 prefect
# 14 preferred
# 9 prehistoric
# 10 prejudices
# 14 premises
# 12 prepare
# 65 prepared
# 9 preparing
# 85 presence
# 170 present
# 56 presented
# 42 presently
# 19 preservation
# 18 preserve
# 19 preserved
# 10 president
# 22 press
# 28 pressed
# 10 pressing
# 25 pressure
# 15 presume
# 13 pretend
# 34 pretty
# 12 prevailed
# 38 prevent
# 33 prevented
# 25 previous
# 22 previously
# 23 prey
# 17 price
# 42 pride
# 10 priest
# 12 priests
# 13 primal
# 16 primitive
# 19 prince
# 10 princess
# 24 principal
# 12 principally
# 49 principle
# 21 principles
# 14 print
# 10 printed
# 19 prints
# 27 prison
# 26 private
# 12 prize
# 15 probability
# 28 probable
# 54 probably
# 44 proceed
# 85 proceeded
# 17 proceeding
# 10 proceedings
# 17 process
# 10 procure
# 9 procured
# 33 prodigious
# 20 produce
# 48 produced
# 15 profession
# 48 professor
# 9 professors
# 45 profound
# 14 profoundly
# 64 progress
# 13 project
# 9 projects
# 9 prominent
# 57 promise
# 42 promised
# 12 promises
# 9 prompted
# 19 pronounced
# 20 proof
# 52 proper
# 35 properly
# 12 properties
# 20 property
# 43 proportion
# 17 proportions
# 11 propose
# 17 proposed
# 15 proposition
# 30 prospect
# 14 prosperity
# 12 protect
# 13 protection
# 29 protector
# 10 protectors
# 19 proud
# 40 prove
# 52 proved
# 20 provided
# 14 providence
# 11 province
# 10 prudence
# 10 psyche
# 78 public
# 13 published
# 14 puff
# 18 pull
# 16 pulled
# 10 pulling
# 12 pulse
# 12 pundit
# 12 purchase
# 45 pure
# 24 purple
# 102 purpose
# 29 purposes
# 24 pursue
# 29 pursued
# 27 pursuit
# 16 pursuits
# 16 pushed
# 160 put
# 29 putting
# 19 puzzled
# 13 quaint
# 26 qualities
# 34 quality
# 36 quantity
# 28 quarter
# 15 quarters
# 14 que
# 21 queen
# 64 queer
# 10 queerly
# 21 quest
# 125 question
# 19 questioned
# 37 questions
# 43 quick
# 61 quickly
# 54 quiet
# 28 quietly
# 31 quit
# 140 quite
# 38 quitted
# 15 quitting
# 16 quivering
# 13 quoted
# 49 race
# 11 radiance
# 23 radiant
# 9 radical
# 39 rage
# 9 ragged
# 9 railway
# 65 rain
# 27 raise
# 41 raised
# 16 raising
# 9 rambling
# 57 ran
# 9 randolph
# 10 rang
# 13 range
# 32 rank
# 37 rapid
# 16 rapidity
# 52 rapidly
# 9 rapture
# 33 rare
# 10 rash
# 28 rat
# 24 rate
# 177 rather
# 10 ratio
# 13 rational
# 13 rats
# 12 rattling
# 11 ravages
# 10 ravine
# 14 ray
# 272 raymond
# 38 rays
# 66 reach
# 112 reached
# 18 reaching
# 132 read
# 23 reader
# 15 readers
# 32 readily
# 40 reading
# 49 ready
# 75 real
# 10 realise
# 15 realised
# 61 reality
# 100 really
# 13 realms
# 10 reanimation
# 30 rear
# 10 reared
# 145 reason
# 16 reasonable
# 11 reasoning
# 24 reasons
# 49 recall
# 25 recalled
# 33 receive
# 92 received
# 17 receiving
# 16 recent
# 10 recess
# 20 recesses
# 20 recognised
# 17 recognized
# 10 recollect
# 26 recollection
# 21 recollections
# 38 record
# 16 recorded
# 14 records
# 9 recourse
# 11 recover
# 41 recovered
# 12 recovery
# 81 red
# 20 reduced
# 29 reef
# 9 reeling
# 11 refer
# 31 reference
# 10 referred
# 12 refined
# 24 reflect
# 47 reflected
# 11 reflecting
# 52 reflection
# 27 reflections
# 12 refuge
# 10 refusal
# 20 refuse
# 30 refused
# 10 regal
# 75 regard
# 50 regarded
# 20 regarding
# 18 regards
# 53 region
# 37 regions
# 25 regret
# 10 regretted
# 26 regular
# 10 regulated
# 11 reign
# 25 relate
# 30 related
# 34 relation
# 18 relations
# 17 relative
# 19 relatives
# 54 relief
# 13 relieve
# 22 relieved
# 10 reluctance
# 10 reluctant
# 69 remain
# 138 remained
# 25 remaining
# 41 remains
# 22 remark
# 56 remarkable
# 11 remarkably
# 14 remarked
# 14 remedy
# 101 remember
# 61 remembered
# 14 remembrance
# 9 remind
# 11 reminded
# 11 remnant
# 31 remorse
# 57 remote
# 13 removal
# 18 remove
# 37 removed
# 11 removing
# 29 render
# 65 rendered
# 19 renewed
# 9 renown
# 14 rent
# 9 repaired
# 32 repeat
# 40 repeated
# 15 repellent
# 11 repetition
# 10 replaced
# 10 replete
# 119 replied
# 53 reply
# 17 report
# 40 repose
# 15 reposed
# 21 represented
# 12 reproach
# 10 republic
# 10 repulsive
# 18 reputation
# 31 request
# 10 requested
# 19 require
# 29 required
# 12 requires
# 10 requisite
# 13 rescue
# 9 research
# 11 researches
# 24 resemblance
# 14 resemble
# 15 resembled
# 15 resembling
# 13 resentment
# 14 reserved
# 15 resided
# 29 residence
# 11 resignation
# 18 resist
# 21 resistance
# 22 resolution
# 15 resolve
# 87 resolved
# 9 resource
# 9 resources
# 60 respect
# 13 respectable
# 11 respecting
# 10 respects
# 10 response
# 120 rest
# 24 rested
# 22 restless
# 23 restore
# 36 restored
# 9 restrain
# 69 result
# 39 results
# 24 resumed
# 9 retain
# 11 retained
# 32 retired
# 20 retreat
# 11 retreated
# 168 return
# 119 returned
# 24 returning
# 22 revealed
# 10 revellers
# 35 revenge
# 10 reverence
# 10 reveries
# 10 revive
# 15 revived
# 28 revolution
# 12 revolver
# 36 reward
# 12 rice
# 56 rich
# 18 rid
# 22 ride
# 186 right
# 22 rigid
# 26 rim
# 31 ring
# 11 ringing
# 61 rise
# 12 risen
# 38 rising
# 13 risk
# 15 rites
# 11 ritual
# 13 rival
# 111 river
# 12 rivers
# 13 riveted
# 76 road
# 9 roads
# 11 roar
# 10 roared
# 9 roaring
# 9 robber
# 16 robe
# 17 robert
# 63 rock
# 27 rocks
# 16 rocky
# 14 rod
# 24 rode
# 21 rog
# 11 roll
# 30 rolled
# 27 roman
# 15 rome
# 15 romero
# 45 roof
# 31 roofs
# 304 room
# 39 rooms
# 18 roots
# 31 rope
# 88 rose
# 16 rotterdam
# 17 rotting
# 27 rough
# 10 roule
# 87 round
# 11 rouse
# 14 roused
# 26 route
# 17 routine
# 10 rowdy
# 17 royal
# 11 rud
# 13 rudder
# 11 rude
# 36 rue
# 9 rugged
# 42 ruin
# 26 ruined
# 33 ruins
# 23 rule
# 10 ruled
# 9 rumbling
# 14 rumour
# 37 run
# 23 running
# 26 rush
# 47 rushed
# 26 rushing
# 29 ryland
# 25 sacred
# 20 sacrifice
# 9 sacrificed
# 52 sad
# 10 sadly
# 25 safe
# 33 safety
# 20 safie
# 704 said
# 32 sail
# 23 sailed
# 20 sailor
# 18 sailors
# 10 sails
# 43 sake
# 11 salt
# 16 sane
# 12 sang
# 10 sanity
# 33 sank
# 20 sarnath
# 121 sat
# 19 satisfaction
# 10 satisfactory
# 50 satisfied
# 19 satisfy
# 24 savage
# 94 save
# 22 saved
# 502 saw
# 13 sawyer
# 409 say
# 29 saying
# 79 says
# 12 scale
# 16 scarab
# 14 scarce
# 99 scarcely
# 34 scattered
# 169 scene
# 24 scenery
# 44 scenes
# 13 scheme
# 10 schemes
# 13 scholar
# 39 school
# 9 schools
# 52 science
# 24 scientific
# 12 scorn
# 11 scotland
# 12 scratching
# 25 scream
# 23 screamed
# 26 screaming
# 26 screams
# 16 scrutiny
# 13 sculptor
# 243 sea
# 15 sealed
# 14 seaman
# 14 seamen
# 53 search
# 10 searched
# 22 seas
# 28 season
# 10 seasons
# 42 seat
# 31 seated
# 14 seats
# 16 secluded
# 15 seclusion
# 154 second
# 15 seconds
# 110 secret
# 39 secrets
# 10 section
# 33 secure
# 24 secured
# 12 securely
# 14 security
# 411 see
# 13 seed
# 34 seeing
# 67 seek
# 27 seeking
# 57 seem
# 544 seemed
# 14 seeming
# 23 seemingly
# 58 seems
# 282 seen
# 10 sees
# 12 seize
# 64 seized
# 14 seizing
# 42 seldom
# 18 selected
# 103 self
# 11 selfish
# 11 semblance
# 13 semi
# 18 send
# 41 sensation
# 48 sensations
# 136 sense
# 64 senses
# 21 sensibility
# 21 sensitive
# 57 sent
# 28 sentence
# 53 sentiment
# 19 sentiments
# 10 sentinel
# 16 separate
# 14 separated
# 11 separation
# 16 september
# 9 sepulchre
# 15 serene
# 35 series
# 35 serious
# 10 serpent
# 47 servant
# 29 servants
# 15 serve
# 30 served
# 16 service
# 14 services
# 153 set
# 29 setting
# 29 settled
# 54 seven
# 11 seventeenth
# 14 seventh
# 12 seventy
# 156 several
# 19 severe
# 20 shade
# 9 shaded
# 12 shades
# 98 shadow
# 12 shadowed
# 49 shadows
# 26 shadowy
# 19 shake
# 18 shaken
# 15 shaking
# 368 shall
# 18 shame
# 48 shape
# 17 shaped
# 33 shapes
# 14 share
# 13 shared
# 36 sharp
# 10 sharply
# 17 shattered
# 22 shed
# 14 sheehan
# 10 sheep
# 17 sheer
# 16 sheet
# 12 shell
# 20 shelter
# 12 sheltered
# 11 shepherd
# 30 shew
# 58 shewed
# 17 shewing
# 14 shewn
# 12 shield
# 12 shifting
# 12 shine
# 24 shining
# 75 ship
# 10 ships
# 10 shiver
# 12 shivered
# 27 shock
# 27 shocking
# 36 shone
# 35 shook
# 10 shoot
# 20 shop
# 69 shore
# 15 shores
# 111 short
# 9 shorter
# 21 shortly
# 30 shot
# 32 shoulder
# 15 shoulders
# 11 shout
# 13 shouted
# 10 shouts
# 30 show
# 12 showed
# 13 shown
# 14 shrank
# 24 shriek
# 20 shrieked
# 19 shrieking
# 18 shrieks
# 25 shrill
# 10 shrine
# 10 shrivelled
# 14 shroud
# 28 shudder
# 36 shuddered
# 20 shuddering
# 30 shunned
# 53 shut
# 12 shutter
# 14 shutters
# 10 shutting
# 22 sic
# 25 sick
# 15 sickened
# 10 sickening
# 10 sickly
# 19 sickness
# 177 side
# 46 sides
# 21 sigh
# 12 sighs
# 162 sight
# 25 sights
# 31 sign
# 12 signal
# 13 significance
# 44 signs
# 102 silence
# 80 silent
# 16 silently
# 20 silk
# 11 silly
# 40 silver
# 62 similar
# 78 simple
# 13 simplicity
# 22 simply
# 10 simpson
# 9 simultaneously
# 9 sin
# 242 since
# 12 sincerely
# 14 sing
# 16 singing
# 86 single
# 85 singular
# 27 singularly
# 50 sinister
# 20 sink
# 13 sinking
# 100 sir
# 87 sister
# 9 sisters
# 30 sit
# 34 sitting
# 21 situated
# 54 situation
# 90 six
# 17 sixteen
# 9 sixth
# 16 sixty
# 52 size
# 10 skeleton
# 10 sketch
# 12 skies
# 14 skill
# 18 skin
# 42 skull
# 115 sky
# 17 slab
# 14 slanting
# 22 slater
# 17 slave
# 143 sleep
# 10 sleeper
# 20 sleeping
# 14 slender
# 55 slept
# 79 slight
# 41 slightest
# 30 slightly
# 22 slip
# 29 slope
# 12 slopes
# 43 slow
# 57 slowly
# 23 slumber
# 231 small
# 18 smaller
# 20 smell
# 62 smile
# 25 smiled
# 27 smiles
# 35 smith
# 22 smoke
# 11 smooth
# 10 snatched
# 40 snow
# 11 snowy
# 9 snuff
# 19 sober
# 21 social
# 76 society
# 49 soft
# 21 softened
# 17 softly
# 17 soil
# 11 soldier
# 24 soldiers
# 66 sole
# 41 solemn
# 9 solemnly
# 27 solid
# 37 solitary
# 59 solitude
# 44 solution
# 12 somebody
# 20 somehow
# 11 someone
# 222 something
# 169 sometimes
# 92 somewhat
# 20 somewhere
# 71 son
# 24 song
# 21 songs
# 14 sons
# 270 soon
# 17 sooner
# 12 soothe
# 17 soothed
# 19 soothing
# 81 sorrow
# 10 sorrowful
# 18 sorrows
# 21 sorry
# 67 sort
# 12 sothoth
# 96 sought
# 232 soul
# 20 souls
# 166 sound
# 21 sounded
# 81 sounds
# 40 source
# 13 sources
# 75 south
# 22 southern
# 18 southward
# 11 sovereign
# 118 space
# 12 spaces
# 19 spanish
# 12 spared
# 10 spark
# 147 speak
# 15 speaker
# 42 speaking
# 14 speaks
# 11 special
# 41 species
# 20 specimen
# 25 specimens
# 12 spectacle
# 11 spectacles
# 29 spectators
# 30 spectral
# 16 speculation
# 14 speculations
# 38 speech
# 24 speed
# 14 speedily
# 12 speedy
# 18 spell
# 15 spend
# 72 spent
# 11 sphere
# 13 spheres
# 9 spinning
# 202 spirit
# 53 spirits
# 11 spiritual
# 33 spite
# 18 splendid
# 9 splendor
# 20 splendour
# 10 split
# 163 spoke
# 43 spoken
# 9 sport
# 99 spot
# 20 spots
# 18 sprang
# 58 spread
# 12 spreading
# 66 spring
# 13 springing
# 20 sprung
# 14 squalid
# 36 square
# 15 squatters
# 68 st
# 12 stable
# 39 stage
# 15 staggered
# 15 stained
# 23 staircase
# 39 stairs
# 34 stand
# 30 standing
# 19 stands
# 52 star
# 12 stared
# 16 staring
# 10 stark
# 76 stars
# 17 start
# 51 started
# 15 starting
# 23 startled
# 23 startling
# 151 state
# 23 stated
# 17 stately
# 9 states
# 40 station
# 16 statue
# 10 statues
# 15 stature
# 33 stay
# 12 stayed
# 34 steadily
# 21 steady
# 13 steal
# 14 steel
# 23 steep
# 16 steeple
# 17 stench
# 64 step
# 20 stepped
# 96 steps
# 21 stern
# 16 stiff
# 519 still
# 12 sting
# 16 stirred
# 11 stirring
# 11 stole
# 126 stone
# 46 stones
# 163 stood
# 26 stop
# 33 stopped
# 16 store
# 19 stories
# 55 storm
# 72 story
# 13 stout
# 14 str
# 12 straight
# 19 strain
# 283 strange
# 33 strangely
# 17 strangeness
# 47 stranger
# 18 strangers
# 10 straw
# 37 stream
# 12 streamed
# 17 streams
# 178 street
# 82 streets
# 84 strength
# 12 stretch
# 32 stretched
# 9 strewed
# 30 stricken
# 9 strict
# 17 striking
# 9 strip
# 13 stroke
# 68 strong
# 23 stronger
# 20 strongly
# 26 strove
# 76 struck
# 14 structure
# 33 struggle
# 30 struggled
# 27 struggles
# 14 struggling
# 11 stuck
# 15 student
# 28 studied
# 33 studies
# 58 study
# 12 stuff
# 11 stuffed
# 12 stumbled
# 14 stupendous
# 11 stupor
# 30 style
# 10 subdue
# 14 subdued
# 102 subject
# 10 subjected
# 26 subjects
# 13 sublime
# 13 submit
# 16 subsequent
# 12 subsequently
# 11 subsided
# 34 substance
# 9 subterranean
# 9 subtly
# 15 succeed
# 64 succeeded
# 58 success
# 23 succession
# 56 sudden
# 151 suddenly
# 25 suffer
# 64 suffered
# 10 sufferer
# 43 suffering
# 13 sufferings
# 10 sufficed
# 72 sufficient
# 64 sufficiently
# 18 suggest
# 41 suggested
# 32 suggestion
# 11 suggestions
# 12 suicide
# 10 suit
# 9 suitable
# 17 sullen
# 27 sum
# 62 summer
# 41 summit
# 9 summits
# 15 summoned
# 172 sun
# 31 sunday
# 39 sunk
# 20 sunken
# 21 sunset
# 16 sunshine
# 27 superior
# 11 superiority
# 23 superstition
# 12 superstitious
# 11 supper
# 12 supplied
# 28 supply
# 25 support
# 12 supported
# 63 suppose
# 65 supposed
# 17 supposing
# 16 supposition
# 26 supreme
# 119 sure
# 44 surely
# 85 surface
# 9 surmounted
# 16 surpassing
# 32 surprise
# 31 surprised
# 9 surround
# 22 surrounded
# 23 surrounding
# 13 survey
# 15 survive
# 12 survived
# 11 survivors
# 17 susceptible
# 21 suspect
# 34 suspected
# 17 suspended
# 41 suspicion
# 9 suspicions
# 15 sustain
# 13 sustained
# 23 swallowed
# 16 swamp
# 10 swaying
# 14 swear
# 11 sweep
# 92 sweet
# 11 sweetest
# 11 swelled
# 27 swept
# 16 swift
# 14 swiftly
# 15 sword
# 15 swung
# 13 syllable
# 14 syllables
# 10 symbol
# 66 sympathy
# 15 symptoms
# 55 system
# 96 table
# 10 tables
# 10 tail
# 10 tainted
# 207 take
# 168 taken
# 19 takes
# 69 taking
# 21 talbot
# 77 tale
# 9 talent
# 17 talents
# 45 tales
# 60 talk
# 62 talked
# 25 talking
# 60 tall
# 10 tame
# 11 taown
# 11 tarpaulin
# 62 task
# 32 taste
# 26 taught
# 24 te
# 16 tea
# 22 tear
# 126 tears
# 46 teeth
# 9 telephone
# 20 telescope
# 188 tell
# 21 telling
# 9 teloth
# 14 temper
# 17 temperament
# 41 tempest
# 51 temple
# 26 temples
# 11 tempted
# 88 ten
# 11 tended
# 11 tendency
# 16 tender
# 31 tenderness
# 11 ter
# 38 term
# 23 termed
# 29 terms
# 11 terrace
# 146 terrible
# 29 terrific
# 18 terrified
# 106 terror
# 19 terrors
# 13 test
# 11 testimony
# 45 th
# 25 thank
# 13 thar
# 16 theatre
# 56 thee
# 15 theme
# 23 thence
# 24 theories
# 21 theory
# 10 thereafter
# 118 therefore
# 17 therein
# 46 thick
# 25 thicket
# 12 thickly
# 50 thin
# 356 thing
# 369 things
# 14 thingum
# 208 think
# 37 thinking
# 10 thinks
# 74 third
# 20 thirst
# 13 thirteen
# 40 thirty
# 19 thither
# 17 thomas
# 15 thorough
# 29 thoroughly
# 83 thou
# 318 though
# 442 thought
# 134 thoughts
# 163 thousand
# 16 thousands
# 11 threat
# 18 threatened
# 265 three
# 15 threshold
# 76 threw
# 14 thrilling
# 31 throat
# 21 throne
# 12 throng
# 11 thronged
# 32 throughout
# 35 throw
# 29 throwing
# 86 thrown
# 27 thrust
# 38 thunder
# 405 thus
# 74 thy
# 9 tiara
# 26 tide
# 14 tied
# 10 ties
# 14 tightly
# 132 till
# 18 tillinghast
# 730 time
# 139 times
# 9 tinged
# 10 tinted
# 18 tiny
# 9 tired
# 12 tis
# 12 tissue
# 9 titan
# 10 titanic
# 30 title
# 126 together
# 20 toil
# 9 toiled
# 13 toils
# 217 told
# 68 tomb
# 16 tombs
# 52 tone
# 29 tones
# 35 tongue
# 9 tongues
# 227 took
# 75 top
# 28 topic
# 12 topics
# 14 torch
# 22 tore
# 42 torn
# 27 torture
# 9 tortured
# 10 tossed
# 33 total
# 16 totally
# 10 tottered
# 15 tottering
# 42 touch
# 29 touched
# 19 touching
# 10 tour
# 140 toward
# 171 towards
# 34 tower
# 15 towers
# 159 town
# 27 towns
# 52 trace
# 20 traced
# 30 traces
# 15 track
# 15 tracks
# 23 trade
# 12 tradition
# 21 tragedy
# 10 trail
# 27 train
# 13 tranquil
# 23 tranquillity
# 13 transport
# 11 travel
# 13 travelled
# 13 traveller
# 18 travellers
# 13 travelling
# 30 treasure
# 14 treated
# 68 tree
# 134 trees
# 12 tremble
# 28 trembled
# 35 trembling
# 27 tremendous
# 14 trever
# 21 trial
# 11 tribe
# 80 tried
# 12 trifle
# 11 trifling
# 36 triumph
# 14 triumphant
# 13 trivial
# 13 trod
# 14 troops
# 50 trouble
# 22 troubled
# 154 true
# 38 truly
# 16 trunk
# 10 trunks
# 28 trust
# 9 trusted
# 141 truth
# 49 try
# 13 trying
# 11 tube
# 17 tumult
# 12 tumultuous
# 26 turk
# 10 turkish
# 14 turks
# 81 turn
# 181 turned
# 42 turning
# 11 turns
# 19 twelve
# 91 twenty
# 28 twice
# 33 twilight
# 12 twisted
# 431 two
# 16 type
# 11 tyranny
# 13 tyrant
# 11 ud
# 14 ugh
# 14 ugly
# 12 ulthar
# 32 ultimate
# 13 una
# 53 unable
# 20 unaccountable
# 12 uncanny
# 15 uncertain
# 89 uncle
# 17 unconscious
# 10 uncouth
# 11 uncovered
# 78 understand
# 41 understanding
# 47 understood
# 14 undertaking
# 12 undisturbed
# 26 undoubtedly
# 14 unearthly
# 15 uneasiness
# 17 uneasy
# 20 unexpected
# 31 unfortunate
# 12 unhallowed
# 10 unhappiness
# 43 unhappy
# 10 unheard
# 10 unintelligible
# 25 union
# 27 united
# 27 universal
# 46 universe
# 33 university
# 126 unknown
# 28 unless
# 25 unlike
# 10 unlocked
# 9 unmistakable
# 11 unnamable
# 32 unnatural
# 11 unparalleled
# 9 unpleasant
# 10 unquiet
# 12 unreal
# 28 unseen
# 23 untill
# 19 unto
# 53 unusual
# 17 unusually
# 17 unutterable
# 12 unwholesome
# 12 unwilling
# 10 unworthy
# 1411 upon
# 46 upper
# 10 upright
# 11 uproar
# 29 upward
# 43 urged
# 613 us
# 96 use
# 58 used
# 10 useful
# 27 useless
# 14 usher
# 14 using
# 96 usual
# 44 usually
# 19 utmost
# 54 utter
# 18 utterance
# 40 uttered
# 74 utterly
# 9 uttermost
# 27 vacant
# 11 vagabond
# 68 vague
# 18 vaguely
# 73 vain
# 18 vainly
# 22 valdemar
# 10 vale
# 76 valley
# 11 valleys
# 28 value
# 42 vanished
# 16 vapours
# 10 variation
# 15 varied
# 25 variety
# 86 various
# 127 vast
# 11 vat
# 30 vault
# 22 vegetation
# 11 vehicle
# 21 veil
# 11 veiled
# 15 veins
# 21 velocity
# 11 velvet
# 17 venerable
# 21 vengeance
# 9 venture
# 27 ventured
# 10 verdant
# 10 verge
# 10 verney
# 10 verses
# 52 vessel
# 12 vessels
# 21 vice
# 33 vicinity
# 49 victim
# 16 victims
# 23 victor
# 27 victory
# 130 view
# 19 viewed
# 18 views
# 10 vigorous
# 64 village
# 17 villagers
# 12 villain
# 12 vine
# 11 viol
# 48 violence
# 47 violent
# 29 violently
# 24 violet
# 22 virtue
# 15 virtues
# 12 virtuous
# 86 visible
# 61 vision
# 35 visions
# 74 visit
# 11 visitation
# 53 visited
# 18 visitor
# 12 visitors
# 17 visits
# 13 vista
# 10 vistas
# 15 vital
# 11 vitality
# 32 vivid
# 12 vividly
# 10 vividness
# 271 voice
# 51 voices
# 17 void
# 22 volume
# 10 volumes
# 33 von
# 10 vondervotteimittiss
# 12 vortex
# 12 vow
# 12 vowed
# 9 vows
# 42 voyage
# 15 vulgar
# 11 wa
# 13 wade
# 28 wait
# 38 waited
# 14 waiting
# 9 waker
# 27 waking
# 9 wal
# 44 walk
# 58 walked
# 30 walking
# 13 walks
# 115 wall
# 125 walls
# 18 wander
# 45 wandered
# 17 wandering
# 18 wanderings
# 13 waning
# 60 want
# 22 wanted
# 10 wanting
# 19 wants
# 48 war
# 41 warm
# 20 warmth
# 10 warning
# 19 warren
# 17 washington
# 21 waste
# 60 watch
# 57 watched
# 11 watches
# 38 watching
# 195 water
# 11 waterfront
# 66 waters
# 12 watery
# 22 wave
# 11 waved
# 47 waves
# 12 waving
# 10 wax
# 304 way
# 21 ways
# 44 weak
# 9 weaker
# 31 weakness
# 37 wealth
# 13 wealthy
# 13 wear
# 11 wearied
# 9 weariness
# 19 weary
# 36 weather
# 16 weeds
# 57 week
# 47 weeks
# 26 weep
# 14 weeping
# 19 weighed
# 54 weight
# 33 weird
# 22 welcome
# 13 welcomed
# 473 well
# 217 went
# 39 wept
# 149 west
# 19 western
# 16 wet
# 13 whar
# 11 wharf
# 53 whateley
# 12 whateleys
# 59 whatever
# 14 wheel
# 9 wheels
# 27 whence
# 25 whenever
# 10 wherefore
# 22 wherein
# 11 wherever
# 85 whether
# 66 whilst
# 12 whippoorwills
# 15 whirl
# 10 whiskey
# 28 whisper
# 45 whispered
# 10 whispering
# 15 whispers
# 147 white
# 28 whither
# 16 whoever
# 297 whole
# 9 wholesome
# 51 wholly
# 401 whose
# 10 wicked
# 92 wide
# 15 widely
# 11 widow
# 87 wife
# 35 wilbur
# 19 wilcox
# 157 wild
# 13 wilder
# 16 wilderness
# 25 wildest
# 31 wildly
# 32 william
# 22 willing
# 19 wilson
# 17 win
# 137 wind
# 16 winding
# 130 window
# 107 windows
# 41 winds
# 73 windsor
# 36 wine
# 15 wing
# 17 winged
# 41 wings
# 62 winter
# 39 wisdom
# 42 wise
# 111 wish
# 74 wished
# 33 wishes
# 11 wishing
# 23 wit
# 17 witch
# 300 within
# 377 without
# 24 witness
# 15 witnessed
# 19 witnesses
# 10 wizard
# 22 woe
# 93 woman
# 31 women
# 110 wonder
# 33 wondered
# 39 wonderful
# 24 wonders
# 15 wondrous
# 13 wont
# 68 wood
# 10 wooded
# 12 wooden
# 53 woods
# 20 woodville
# 136 word
# 292 words
# 33 wore
# 145 work
# 25 worked
# 14 working
# 9 workmanship
# 29 works
# 323 world
# 12 worldly
# 13 worlds
# 16 worm
# 31 worn
# 33 worse
# 15 worship
# 9 worshipped
# 33 worst
# 25 worth
# 34 worthy
# 1241 would
# 24 wound
# 14 wounded
# 16 wounds
# 15 wrapped
# 10 wrapt
# 16 wrath
# 15 wreck
# 36 wretch
# 28 wretched
# 31 wretchedness
# 10 wrinkled
# 12 wrist
# 52 write
# 21 writer
# 11 writers
# 15 writhing
# 33 writing
# 46 written
# 35 wrong
# 42 wrote
# 27 wrought
# 23 wyatt
# 23 yard
# 18 yards
# 9 yawned
# 9 yawning
# 99 ye
# 99 year
# 346 years
# 45 yellow
# 78 yes
# 19 yesterday
# 715 yet
# 24 yield
# 23 yielded
# 12 yog
# 23 york
# 228 young
# 22 younger
# 104 youth
# 18 youthful
# 14 yxu
# 16 zadok
# 16 zann
# 17 zeal
# 10 zenobia

# %%
print ("Training the random forest...")
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
# This may take a few minutes to run
forest = forest.fit( train_data_features, train["author"] )
print('training over')
# Out:
# Training the random forest...
# training over

# %%
# Read the test data
test = pd.read_csv("test.csv")
test = test[['id', 'text']]
print(test.shape)
print(test.columns)
print(review_to_words( test["text"][0] ))
# Create an empty list and append the clean reviews one by one
num_reviews = len(test["text"])
clean_test_reviews = [] 

i = 0

while i < num_reviews:
    clean_review = review_to_words( test["text"][i])
    clean_test_reviews.append(clean_review )
    i += 1
# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_reviews)
test_data_features = test_data_features.toarray()

# Use the random forest to make sentiment label predictions
result = forest.predict(test_data_features)
print(num_reviews)
print(len(result))
print(result)
# Out:
# (8392, 2)
# Index(['id', 'text'], dtype='object')
# still urged leaving ireland inquietude impatience father thought best yield
# /home/reuglewi/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/reuglewi/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 8392
# 8392
# ['MWS' 'EAP' 'HPL' ..., 'EAP' 'MWS' 'EAP']

# %%
# Read the test data
test = pd.read_csv("test.csv")
test = test[['id', 'text']]
print(test.shape)
print(test.columns)
# Create an empty list and append the clean reviews one by one
num_reviews = len(test["text"])
clean_test_reviews = [] 
# Create an empty list and append the clean reviews one by one
print ("Cleaning and parsing the test set movie reviews...\n")
for i in range(0,num_reviews):
    if( (i+1) % 1000 == 0 ):
        print ("Review %d of %d\n" % (i+1, num_reviews))
        clean_review = review_to_words( test["text"][i] )
        clean_test_reviews.append( clean_review )

# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_reviews)
test_data_features = test_data_features.toarray()

# Use the random forest to make sentiment label predictions
result = forest.predict(test_data_features)
# Copy the results to a pandas dataframe with an "id" column and
# a "sentiment" column
output = pd.DataFrame( data={"id":test["id"], "author":result} )

# Use pandas to write the comma-separated output file
output.to_csv( "sample_submission.csv", index=False, quoting=3 )
# Out:
# (8392, 2)
# Index(['id', 'text'], dtype='object')
# still urged leaving ireland inquietude impatience father thought best yield
# Cleaning and parsing the test set movie reviews...
#
# Review 1000 of 8392
#
# Review 2000 of 8392
#
# Review 3000 of 8392
#
# Review 4000 of 8392
#
# Review 5000 of 8392
#
# Review 6000 of 8392
#
# Review 7000 of 8392
#
# Review 8000 of 8392
# /home/reuglewi/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/reuglewi/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2180472565c1> in <module>()
#      25 # Copy the results to a pandas dataframe with an "id" column and
#      26 # a "sentiment" column
# ---> 27 output = pd.DataFrame( data={"id":test["id"], "author":result} )
#      28
#      29 # Use pandas to write the comma-separated output file
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5494     # figure out the index, if necessary
#    5495     if index is None:
# -> 5496         index = extract_index(arrays)
#    5497     else:
#    5498         index = _ensure_index(index)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    5552                     msg = ('array length %d does not match index length %d' %
#    5553                            (lengths[0], len(index)))
# -> 5554                     raise ValueError(msg)
#    5555             else:
#    5556                 index = _default_index(lengths[0])
#
# ValueError: array length 8 does not match index length 8392

# %%
srce = pd.read_csv("sample_submission.csv")
test = pd.read_csv("test_happy.csv")
test = test[['Description']]
print(test.head(1))
print((srce.head(10)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-60d7891b7ebc> in <module>()
# ----> 1 srce = pd.read_csv("sample_submission.csv")
#       2 test = pd.read_csv("test_happy.csv")
#       3 test = test[['Description']]
#       4 print(test.head(1))
#       5 print((srce.head(10)))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'sample_submission.csv' does not exist
